# %% [markdown]
# # Line Chart

# %%
import matplotlib.pyplot as plt

# %%
title = "Line Chart"
x_label = "X Axis"
y_label = "Y Axis"

x_data = [1, 2, 3, 4, 5, 6]
y_data = [9, 6, 7, 3, 1, 4]

# %%
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.plot(x_data, y_data)
