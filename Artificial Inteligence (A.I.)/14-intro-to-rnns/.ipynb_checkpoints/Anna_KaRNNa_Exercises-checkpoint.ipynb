# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70])

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr) // characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, (batch_size, num_steps), name='inputs')
    targets = tf.placeholder(tf.int32, (batch_size, num_steps), name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    
    ### Build the LSTM Cell
    def build_cell(num_units, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
        # Add dropout to the cell outputs
        return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # That is, the shape should be batch_size*num_steps rows by lstm_size columns
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn 
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss =  build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100         # Sequences per batch
num_steps = 100          # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# WARNING:tensorflow:From <ipython-input-12-f3f8451d5bdf>:18: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4202...  6.6290 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3489...  6.4792 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.9983...  6.4769 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 6.0017...  7.0111 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 4.0961...  8.1571 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.7189...  8.8170 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.6769...  7.5548 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.5975...  7.5281 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.4876...  7.5209 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.4092...  7.6194 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.3415...  7.4684 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.3263...  7.4948 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.2961...  7.4875 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.2960...  7.4620 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.2846...  7.4364 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.2682...  7.4438 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.2671...  7.4368 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.2951...  7.4502 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2732...  7.5322 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.2321...  7.7538 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2359...  7.5244 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2262...  7.4618 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.2121...  7.4659 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.2247...  7.4632 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.2135...  7.4414 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.2226...  7.5605 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.2200...  7.4605 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.1931...  7.9859 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.2030...  7.5950 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.2040...  7.6197 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.2209...  7.4542 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.1935...  7.5326 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1818...  7.4458 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.1912...  6.4650 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1783...  6.3616 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.1905...  6.4008 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1638...  6.3550 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1611...  6.3743 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1586...  6.4125 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1725...  6.3894 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1571...  6.4674 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1620...  6.3835 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1559...  6.4676 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1515...  6.3611 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1473...  6.3433 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1627...  6.3062 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1682...  6.2949 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1653...  6.3037 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1645...  6.3364 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1598...  6.4200 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1538...  6.3439 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.1477...  6.3520 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.1545...  6.3670 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.1337...  6.2954 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.1550...  6.3287 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.1218...  6.3163 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.1434...  6.2944 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1478...  6.3169 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.1267...  6.3812 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1405...  6.3114 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.1405...  6.3086 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.1512...  6.4018 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.1595...  6.6191 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.1133...  6.5157 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.1185...  6.2990 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.1464...  6.3655 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.1439...  6.3493 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.1007...  6.3174 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.1154...  6.2937 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.1329...  6.2998 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.1226...  6.2752 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.1396...  6.2900 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.1137...  6.3045 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.1140...  6.3473 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.1250...  6.3199 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.1280...  6.2849 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.1175...  6.2914 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.1110...  6.2895 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.0989...  6.2782 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.0872...  6.2756 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.0867...  6.4199 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.1350...  6.3635 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.1179...  6.2640 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.1000...  6.2874 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.0852...  6.2645 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.0910...  6.2718 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 3.0912...  6.2875 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.0850...  6.3065 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.1034...  6.3748 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.0961...  6.3464 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.0901...  6.3403 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.0860...  6.3059 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.0844...  6.2889 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.0797...  6.2855 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 3.0723...  6.2752 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 3.0658...  6.2612 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 3.0753...  6.3484 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 3.0624...  6.3577 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 3.0630...  6.2702 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.0499...  6.3675 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 3.0567...  6.2664 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 3.0461...  6.2846 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 3.0422...  6.2844 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 3.0299...  6.3474 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 3.0470...  6.3591 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 3.0447...  6.2978 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 3.0157...  6.3065 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 3.0234...  6.3550 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 3.0245...  6.3281 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 2.9962...  6.3140 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 3.0122...  6.4141 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 3.0137...  6.4901 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 2.9987...  6.3742 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 2.9864...  6.3223 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 2.9822...  6.2958 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 2.9695...  6.3052 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 2.9760...  6.3045 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 2.9809...  6.2752 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 2.9786...  6.3665 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.9560...  6.2659 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.9634...  6.3031 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.9435...  6.3003 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.9264...  6.3042 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.9314...  6.2782 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.9040...  6.2873 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.8719...  6.2507 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.9078...  6.3596 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.9050...  6.3346 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.8880...  6.2604 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.8710...  6.2864 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.8875...  6.2855 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.8425...  6.2845 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.8552...  6.2761 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.8331...  6.2703 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.8163...  6.3047 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.7966...  6.3562 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.8012...  6.3526 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.7962...  6.4170 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.8080...  6.2203 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.7935...  6.2821 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.7864...  6.3885 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.7680...  6.3140 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.7672...  6.3366 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.7435...  6.2545 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.7607...  6.2815 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.7528...  6.2836 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.7416...  6.2645 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.7539...  6.2851 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.7017...  6.2588 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.7032...  6.3307 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.7435...  6.3316 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.7297...  6.2620 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.6980...  6.2805 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.6843...  6.2615 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.6580...  6.2762 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.6520...  6.2806 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.6283...  6.3894 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.6324...  6.3297 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.6079...  6.6038 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.6455...  6.2978 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.6141...  6.3047 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.5831...  6.2757 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.5791...  6.2692 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.6017...  6.2654 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.5907...  6.2983 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.5785...  6.3248 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.5819...  6.2721 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.5744...  6.2847 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.5812...  6.2737 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.5387...  6.2718 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.5642...  6.2914 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.5742...  6.2749 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.5927...  6.3851 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.5836...  6.3223 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.5710...  6.2591 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.5884...  6.3722 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.5298...  6.2556 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.5195...  6.2634 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.5057...  6.2664 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.5071...  6.2442 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.5070...  6.3203 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.5137...  6.3292 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.4950...  6.2850 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.5271...  6.2898 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.5269...  6.2576 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.4973...  6.2664 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.4715...  6.2463 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.4732...  6.3673 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.4710...  6.3415 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.4783...  6.2684 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.4880...  6.2792 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.4554...  6.2726 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.4742...  6.2664 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.4624...  6.2826 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.4609...  6.3822 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.4488...  6.3909 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.4432...  6.3768 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.4443...  6.3071 sec/batch
# Epoch: 2/20...  Training Step: 199...  Training loss: 2.5123...  6.2792 sec/batch
# Epoch: 2/20...  Training Step: 200...  Training loss: 2.4295...  6.2849 sec/batch
# Epoch: 2/20...  Training Step: 201...  Training loss: 2.4289...  6.2433 sec/batch
# Epoch: 2/20...  Training Step: 202...  Training loss: 2.4493...  6.4007 sec/batch
# Epoch: 2/20...  Training Step: 203...  Training loss: 2.4481...  6.3680 sec/batch
# Epoch: 2/20...  Training Step: 204...  Training loss: 2.4376...  6.6280 sec/batch
# Epoch: 2/20...  Training Step: 205...  Training loss: 2.4464...  6.8148 sec/batch
# Epoch: 2/20...  Training Step: 206...  Training loss: 2.4451...  7.0891 sec/batch
# Epoch: 2/20...  Training Step: 207...  Training loss: 2.4559...  7.2613 sec/batch
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.4262...  6.3929 sec/batch
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.4241...  6.3788 sec/batch
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.4220...  6.3734 sec/batch
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.4199...  6.4566 sec/batch
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.4621...  6.4465 sec/batch
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.4226...  6.4208 sec/batch
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.4209...  6.3999 sec/batch
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.4210...  6.3680 sec/batch
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.4526...  6.3717 sec/batch
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.4271...  6.3518 sec/batch
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.3968...  6.3572 sec/batch
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.4038...  6.4229 sec/batch
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.4435...  6.5160 sec/batch
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.4114...  6.3660 sec/batch
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.3996...  6.3801 sec/batch
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.3886...  6.3920 sec/batch
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.3928...  6.3399 sec/batch
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.3888...  6.3655 sec/batch
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.3905...  6.3649 sec/batch
# Epoch: 2/20...  Training Step: 227...  Training loss: 2.3958...  6.4043 sec/batch
# Epoch: 2/20...  Training Step: 228...  Training loss: 2.3935...  6.4273 sec/batch
# Epoch: 2/20...  Training Step: 229...  Training loss: 2.4023...  6.3472 sec/batch
# Epoch: 2/20...  Training Step: 230...  Training loss: 2.3658...  6.3395 sec/batch
# Epoch: 2/20...  Training Step: 231...  Training loss: 2.3600...  6.3523 sec/batch
# Epoch: 2/20...  Training Step: 232...  Training loss: 2.3864...  6.4404 sec/batch
# Epoch: 2/20...  Training Step: 233...  Training loss: 2.3630...  6.3430 sec/batch
# Epoch: 2/20...  Training Step: 234...  Training loss: 2.3767...  6.4126 sec/batch
# Epoch: 2/20...  Training Step: 235...  Training loss: 2.3666...  6.4331 sec/batch
# Epoch: 2/20...  Training Step: 236...  Training loss: 2.3344...  6.3405 sec/batch
# Epoch: 2/20...  Training Step: 237...  Training loss: 2.3408...  6.3341 sec/batch
# Epoch: 2/20...  Training Step: 238...  Training loss: 2.3392...  6.3212 sec/batch
# Epoch: 2/20...  Training Step: 239...  Training loss: 2.3447...  6.3753 sec/batch
# Epoch: 2/20...  Training Step: 240...  Training loss: 2.3445...  6.3724 sec/batch
# Epoch: 2/20...  Training Step: 241...  Training loss: 2.3314...  6.3423 sec/batch
# Epoch: 2/20...  Training Step: 242...  Training loss: 2.3273...  6.4430 sec/batch
# Epoch: 2/20...  Training Step: 243...  Training loss: 2.3357...  6.4293 sec/batch
# Epoch: 2/20...  Training Step: 244...  Training loss: 2.2958...  6.4100 sec/batch
# Epoch: 2/20...  Training Step: 245...  Training loss: 2.3567...  6.3856 sec/batch
# Epoch: 2/20...  Training Step: 246...  Training loss: 2.3348...  6.3807 sec/batch
# Epoch: 2/20...  Training Step: 247...  Training loss: 2.3290...  6.3570 sec/batch
# Epoch: 2/20...  Training Step: 248...  Training loss: 2.3460...  6.3503 sec/batch
# Epoch: 2/20...  Training Step: 249...  Training loss: 2.3118...  6.3783 sec/batch
# Epoch: 2/20...  Training Step: 250...  Training loss: 2.3423...  6.4164 sec/batch
# Epoch: 2/20...  Training Step: 251...  Training loss: 2.3159...  6.5573 sec/batch
# Epoch: 2/20...  Training Step: 252...  Training loss: 2.3178...  6.3439 sec/batch
# Epoch: 2/20...  Training Step: 253...  Training loss: 2.3048...  6.5362 sec/batch
# Epoch: 2/20...  Training Step: 254...  Training loss: 2.3236...  6.3905 sec/batch
# Epoch: 2/20...  Training Step: 255...  Training loss: 2.3137...  6.3767 sec/batch
# Epoch: 2/20...  Training Step: 256...  Training loss: 2.3030...  6.4028 sec/batch
# Epoch: 2/20...  Training Step: 257...  Training loss: 2.3132...  6.4306 sec/batch
# Epoch: 2/20...  Training Step: 258...  Training loss: 2.3284...  6.5121 sec/batch
# Epoch: 2/20...  Training Step: 259...  Training loss: 2.3077...  6.3724 sec/batch
# Epoch: 2/20...  Training Step: 260...  Training loss: 2.3208...  6.3542 sec/batch
# Epoch: 2/20...  Training Step: 261...  Training loss: 2.3302...  6.3727 sec/batch
# Epoch: 2/20...  Training Step: 262...  Training loss: 2.2942...  6.3797 sec/batch
# Epoch: 2/20...  Training Step: 263...  Training loss: 2.2911...  6.3636 sec/batch
# Epoch: 2/20...  Training Step: 264...  Training loss: 2.3244...  6.3713 sec/batch
# Epoch: 2/20...  Training Step: 265...  Training loss: 2.3044...  6.5068 sec/batch
# Epoch: 2/20...  Training Step: 266...  Training loss: 2.2594...  6.4239 sec/batch
# Epoch: 2/20...  Training Step: 267...  Training loss: 2.2753...  6.3394 sec/batch
# Epoch: 2/20...  Training Step: 268...  Training loss: 2.2977...  6.3739 sec/batch
# Epoch: 2/20...  Training Step: 269...  Training loss: 2.3084...  6.3660 sec/batch
# Epoch: 2/20...  Training Step: 270...  Training loss: 2.2904...  6.4650 sec/batch
# Epoch: 2/20...  Training Step: 271...  Training loss: 2.2966...  6.3487 sec/batch
# Epoch: 2/20...  Training Step: 272...  Training loss: 2.2704...  6.3606 sec/batch
# Epoch: 2/20...  Training Step: 273...  Training loss: 2.2755...  6.4228 sec/batch
# Epoch: 2/20...  Training Step: 274...  Training loss: 2.3180...  6.4254 sec/batch
# Epoch: 2/20...  Training Step: 275...  Training loss: 2.2736...  6.3509 sec/batch
# Epoch: 2/20...  Training Step: 276...  Training loss: 2.2871...  6.3466 sec/batch
# Epoch: 2/20...  Training Step: 277...  Training loss: 2.2601...  6.3415 sec/batch
# Epoch: 2/20...  Training Step: 278...  Training loss: 2.2598...  6.4269 sec/batch
# Epoch: 2/20...  Training Step: 279...  Training loss: 2.2510...  6.3424 sec/batch
# Epoch: 2/20...  Training Step: 280...  Training loss: 2.2864...  6.4254 sec/batch
# Epoch: 2/20...  Training Step: 281...  Training loss: 2.2392...  6.4375 sec/batch
# Epoch: 2/20...  Training Step: 282...  Training loss: 2.2399...  6.3478 sec/batch
# Epoch: 2/20...  Training Step: 283...  Training loss: 2.2227...  6.3405 sec/batch
# Epoch: 2/20...  Training Step: 284...  Training loss: 2.2426...  6.3366 sec/batch
# Epoch: 2/20...  Training Step: 285...  Training loss: 2.2538...  6.3668 sec/batch
# Epoch: 2/20...  Training Step: 286...  Training loss: 2.2486...  6.3474 sec/batch
# Epoch: 2/20...  Training Step: 287...  Training loss: 2.2203...  6.3380 sec/batch
# Epoch: 2/20...  Training Step: 288...  Training loss: 2.2572...  6.4255 sec/batch
# Epoch: 2/20...  Training Step: 289...  Training loss: 2.2272...  7.0862 sec/batch
# Epoch: 2/20...  Training Step: 290...  Training loss: 2.2415...  6.3876 sec/batch
# Epoch: 2/20...  Training Step: 291...  Training loss: 2.2264...  6.3577 sec/batch
# Epoch: 2/20...  Training Step: 292...  Training loss: 2.2212...  6.3507 sec/batch
# Epoch: 2/20...  Training Step: 293...  Training loss: 2.2222...  6.3400 sec/batch
# Epoch: 2/20...  Training Step: 294...  Training loss: 2.2236...  6.3669 sec/batch
# Epoch: 2/20...  Training Step: 295...  Training loss: 2.2220...  6.3919 sec/batch
# Epoch: 2/20...  Training Step: 296...  Training loss: 2.2225...  6.6128 sec/batch
# Epoch: 2/20...  Training Step: 297...  Training loss: 2.2138...  7.0101 sec/batch
# Epoch: 2/20...  Training Step: 298...  Training loss: 2.2055...  7.0877 sec/batch
# Epoch: 2/20...  Training Step: 299...  Training loss: 2.2300...  7.5410 sec/batch
# Epoch: 2/20...  Training Step: 300...  Training loss: 2.2264...  10.2593 sec/batch
# Epoch: 2/20...  Training Step: 301...  Training loss: 2.1979...  6.9090 sec/batch
# Epoch: 2/20...  Training Step: 302...  Training loss: 2.2090...  6.4522 sec/batch
# Epoch: 2/20...  Training Step: 303...  Training loss: 2.2014...  6.6153 sec/batch
# Epoch: 2/20...  Training Step: 304...  Training loss: 2.2131...  7.3261 sec/batch
# Epoch: 2/20...  Training Step: 305...  Training loss: 2.2100...  7.1886 sec/batch
# Epoch: 2/20...  Training Step: 306...  Training loss: 2.2251...  7.0744 sec/batch
# Epoch: 2/20...  Training Step: 307...  Training loss: 2.2254...  6.3959 sec/batch
# Epoch: 2/20...  Training Step: 308...  Training loss: 2.1993...  6.8536 sec/batch
# Epoch: 2/20...  Training Step: 309...  Training loss: 2.2136...  6.3655 sec/batch
# Epoch: 2/20...  Training Step: 310...  Training loss: 2.2120...  6.3380 sec/batch
# Epoch: 2/20...  Training Step: 311...  Training loss: 2.2033...  6.4125 sec/batch
# Epoch: 2/20...  Training Step: 312...  Training loss: 2.1903...  6.4283 sec/batch
# Epoch: 2/20...  Training Step: 313...  Training loss: 2.1954...  6.3636 sec/batch
# Epoch: 2/20...  Training Step: 314...  Training loss: 2.1569...  6.3507 sec/batch
# Epoch: 2/20...  Training Step: 315...  Training loss: 2.2078...  6.3611 sec/batch
# Epoch: 2/20...  Training Step: 316...  Training loss: 2.1911...  6.3552 sec/batch
# Epoch: 2/20...  Training Step: 317...  Training loss: 2.2095...  6.3536 sec/batch
# Epoch: 2/20...  Training Step: 318...  Training loss: 2.2047...  6.3704 sec/batch
# Epoch: 2/20...  Training Step: 319...  Training loss: 2.2167...  6.4372 sec/batch
# Epoch: 2/20...  Training Step: 320...  Training loss: 2.1887...  6.4247 sec/batch
# Epoch: 2/20...  Training Step: 321...  Training loss: 2.1798...  6.4656 sec/batch
# Epoch: 2/20...  Training Step: 322...  Training loss: 2.2082...  6.4254 sec/batch
# Epoch: 2/20...  Training Step: 323...  Training loss: 2.1823...  6.8030 sec/batch
# Epoch: 2/20...  Training Step: 324...  Training loss: 2.1460...  6.3915 sec/batch
# Epoch: 2/20...  Training Step: 325...  Training loss: 2.1941...  6.3963 sec/batch
# Epoch: 2/20...  Training Step: 326...  Training loss: 2.1971...  6.4151 sec/batch
# Epoch: 2/20...  Training Step: 327...  Training loss: 2.1862...  6.4483 sec/batch
# Epoch: 2/20...  Training Step: 328...  Training loss: 2.1826...  6.5706 sec/batch
# Epoch: 2/20...  Training Step: 329...  Training loss: 2.1582...  6.3749 sec/batch
# Epoch: 2/20...  Training Step: 330...  Training loss: 2.1472...  6.3467 sec/batch
# Epoch: 2/20...  Training Step: 331...  Training loss: 2.1823...  6.3783 sec/batch
# Epoch: 2/20...  Training Step: 332...  Training loss: 2.1856...  6.3483 sec/batch
# Epoch: 2/20...  Training Step: 333...  Training loss: 2.1623...  6.3461 sec/batch
# Epoch: 2/20...  Training Step: 334...  Training loss: 2.1844...  6.4763 sec/batch
# Epoch: 2/20...  Training Step: 335...  Training loss: 2.1741...  6.6538 sec/batch
# Epoch: 2/20...  Training Step: 336...  Training loss: 2.1666...  6.5186 sec/batch
# Epoch: 2/20...  Training Step: 337...  Training loss: 2.2025...  6.3449 sec/batch
# Epoch: 2/20...  Training Step: 338...  Training loss: 2.1590...  6.3723 sec/batch
# Epoch: 2/20...  Training Step: 339...  Training loss: 2.1850...  6.3498 sec/batch
# Epoch: 2/20...  Training Step: 340...  Training loss: 2.1527...  6.3381 sec/batch
# Epoch: 2/20...  Training Step: 341...  Training loss: 2.1559...  6.3649 sec/batch
# Epoch: 2/20...  Training Step: 342...  Training loss: 2.1513...  6.4322 sec/batch
# Epoch: 2/20...  Training Step: 343...  Training loss: 2.1503...  6.6402 sec/batch
# Epoch: 2/20...  Training Step: 344...  Training loss: 2.1715...  6.3665 sec/batch
# Epoch: 2/20...  Training Step: 345...  Training loss: 2.1543...  6.5328 sec/batch
# Epoch: 2/20...  Training Step: 346...  Training loss: 2.1649...  6.3631 sec/batch
# Epoch: 2/20...  Training Step: 347...  Training loss: 2.1539...  6.8076 sec/batch
# Epoch: 2/20...  Training Step: 348...  Training loss: 2.1301...  7.0243 sec/batch
# Epoch: 2/20...  Training Step: 349...  Training loss: 2.1453...  6.6877 sec/batch
# Epoch: 2/20...  Training Step: 350...  Training loss: 2.1879...  6.7250 sec/batch
# Epoch: 2/20...  Training Step: 351...  Training loss: 2.1517...  6.4553 sec/batch
# Epoch: 2/20...  Training Step: 352...  Training loss: 2.1480...  6.4504 sec/batch
# Epoch: 2/20...  Training Step: 353...  Training loss: 2.1346...  7.0033 sec/batch
# Epoch: 2/20...  Training Step: 354...  Training loss: 2.1316...  6.5778 sec/batch
# Epoch: 2/20...  Training Step: 355...  Training loss: 2.1217...  6.4205 sec/batch
# Epoch: 2/20...  Training Step: 356...  Training loss: 2.1367...  6.3331 sec/batch
# Epoch: 2/20...  Training Step: 357...  Training loss: 2.1036...  6.4090 sec/batch
# Epoch: 2/20...  Training Step: 358...  Training loss: 2.1766...  6.3901 sec/batch
# Epoch: 2/20...  Training Step: 359...  Training loss: 2.1519...  6.3214 sec/batch
# Epoch: 2/20...  Training Step: 360...  Training loss: 2.1193...  6.3192 sec/batch
# Epoch: 2/20...  Training Step: 361...  Training loss: 2.1425...  6.2900 sec/batch
# Epoch: 2/20...  Training Step: 362...  Training loss: 2.1239...  6.3528 sec/batch
# Epoch: 2/20...  Training Step: 363...  Training loss: 2.1282...  6.3220 sec/batch
# Epoch: 2/20...  Training Step: 364...  Training loss: 2.1244...  6.7091 sec/batch
# Epoch: 2/20...  Training Step: 365...  Training loss: 2.1287...  8.2769 sec/batch
# Epoch: 2/20...  Training Step: 366...  Training loss: 2.1553...  8.2774 sec/batch
# Epoch: 2/20...  Training Step: 367...  Training loss: 2.1191...  8.4754 sec/batch
# Epoch: 2/20...  Training Step: 368...  Training loss: 2.1052...  8.0051 sec/batch
# Epoch: 2/20...  Training Step: 369...  Training loss: 2.1030...  8.4068 sec/batch
# Epoch: 2/20...  Training Step: 370...  Training loss: 2.1225...  6.5435 sec/batch
# Epoch: 2/20...  Training Step: 371...  Training loss: 2.1295...  6.6579 sec/batch
# Epoch: 2/20...  Training Step: 372...  Training loss: 2.1200...  7.0780 sec/batch
# Epoch: 2/20...  Training Step: 373...  Training loss: 2.1290...  6.8128 sec/batch
# Epoch: 2/20...  Training Step: 374...  Training loss: 2.1136...  6.5667 sec/batch
# Epoch: 2/20...  Training Step: 375...  Training loss: 2.1024...  6.3482 sec/batch
# Epoch: 2/20...  Training Step: 376...  Training loss: 2.1088...  6.3528 sec/batch
# Epoch: 2/20...  Training Step: 377...  Training loss: 2.0926...  6.3900 sec/batch
# Epoch: 2/20...  Training Step: 378...  Training loss: 2.0622...  6.4365 sec/batch
# Epoch: 2/20...  Training Step: 379...  Training loss: 2.0948...  6.4675 sec/batch
# Epoch: 2/20...  Training Step: 380...  Training loss: 2.1140...  6.5410 sec/batch
# Epoch: 2/20...  Training Step: 381...  Training loss: 2.1077...  6.4627 sec/batch
# Epoch: 2/20...  Training Step: 382...  Training loss: 2.1174...  6.3582 sec/batch
# Epoch: 2/20...  Training Step: 383...  Training loss: 2.1047...  6.3433 sec/batch
# Epoch: 2/20...  Training Step: 384...  Training loss: 2.0935...  6.3385 sec/batch
# Epoch: 2/20...  Training Step: 385...  Training loss: 2.0927...  6.3366 sec/batch
# Epoch: 2/20...  Training Step: 386...  Training loss: 2.0677...  6.4944 sec/batch
# Epoch: 2/20...  Training Step: 387...  Training loss: 2.0695...  6.7394 sec/batch
# Epoch: 2/20...  Training Step: 388...  Training loss: 2.0903...  6.6819 sec/batch
# Epoch: 2/20...  Training Step: 389...  Training loss: 2.1043...  6.4548 sec/batch
# Epoch: 2/20...  Training Step: 390...  Training loss: 2.0620...  6.5970 sec/batch
# Epoch: 2/20...  Training Step: 391...  Training loss: 2.1003...  6.3896 sec/batch
# Epoch: 2/20...  Training Step: 392...  Training loss: 2.0774...  6.3595 sec/batch
# Epoch: 2/20...  Training Step: 393...  Training loss: 2.0599...  6.3635 sec/batch
# Epoch: 2/20...  Training Step: 394...  Training loss: 2.0847...  6.6369 sec/batch
# Epoch: 2/20...  Training Step: 395...  Training loss: 2.0822...  6.5444 sec/batch
# Epoch: 2/20...  Training Step: 396...  Training loss: 2.0602...  6.8948 sec/batch
# Epoch: 3/20...  Training Step: 397...  Training loss: 2.1433...  6.4916 sec/batch
# Epoch: 3/20...  Training Step: 398...  Training loss: 2.0484...  6.3753 sec/batch
# Epoch: 3/20...  Training Step: 399...  Training loss: 2.0534...  6.3776 sec/batch
# Epoch: 3/20...  Training Step: 400...  Training loss: 2.0566...  6.3709 sec/batch
# Epoch: 3/20...  Training Step: 401...  Training loss: 2.0672...  6.3007 sec/batch
# Epoch: 3/20...  Training Step: 402...  Training loss: 2.0410...  6.3322 sec/batch
# Epoch: 3/20...  Training Step: 403...  Training loss: 2.0608...  6.4370 sec/batch
# Epoch: 3/20...  Training Step: 404...  Training loss: 2.0584...  6.5632 sec/batch
# Epoch: 3/20...  Training Step: 405...  Training loss: 2.0939...  6.3498 sec/batch
# Epoch: 3/20...  Training Step: 406...  Training loss: 2.0531...  6.3737 sec/batch
# Epoch: 3/20...  Training Step: 407...  Training loss: 2.0478...  6.3204 sec/batch
# Epoch: 3/20...  Training Step: 408...  Training loss: 2.0432...  6.2875 sec/batch
# Epoch: 3/20...  Training Step: 409...  Training loss: 2.0639...  6.2664 sec/batch
# Epoch: 3/20...  Training Step: 410...  Training loss: 2.0901...  6.2966 sec/batch
# Epoch: 3/20...  Training Step: 411...  Training loss: 2.0435...  6.3537 sec/batch
# Epoch: 3/20...  Training Step: 412...  Training loss: 2.0457...  6.5696 sec/batch
# Epoch: 3/20...  Training Step: 413...  Training loss: 2.0469...  6.2976 sec/batch
# Epoch: 3/20...  Training Step: 414...  Training loss: 2.0835...  6.3057 sec/batch
# Epoch: 3/20...  Training Step: 415...  Training loss: 2.0523...  6.3425 sec/batch
# Epoch: 3/20...  Training Step: 416...  Training loss: 2.0506...  6.3482 sec/batch
# Epoch: 3/20...  Training Step: 417...  Training loss: 2.0379...  6.3164 sec/batch
# Epoch: 3/20...  Training Step: 418...  Training loss: 2.0982...  6.3680 sec/batch
# Epoch: 3/20...  Training Step: 419...  Training loss: 2.0478...  6.3685 sec/batch
# Epoch: 3/20...  Training Step: 420...  Training loss: 2.0311...  6.3217 sec/batch
# Epoch: 3/20...  Training Step: 421...  Training loss: 2.0505...  6.2865 sec/batch
# Epoch: 3/20...  Training Step: 422...  Training loss: 2.0313...  6.2787 sec/batch
# Epoch: 3/20...  Training Step: 423...  Training loss: 2.0137...  6.3179 sec/batch
# Epoch: 3/20...  Training Step: 424...  Training loss: 2.0507...  6.2991 sec/batch
# Epoch: 3/20...  Training Step: 425...  Training loss: 2.0637...  6.2993 sec/batch
# Epoch: 3/20...  Training Step: 426...  Training loss: 2.0422...  6.4661 sec/batch
# Epoch: 3/20...  Training Step: 427...  Training loss: 2.0357...  6.3605 sec/batch
# Epoch: 3/20...  Training Step: 428...  Training loss: 2.0014...  6.2797 sec/batch
# Epoch: 3/20...  Training Step: 429...  Training loss: 2.0387...  6.2762 sec/batch
# Epoch: 3/20...  Training Step: 430...  Training loss: 2.0690...  6.2802 sec/batch
# Epoch: 3/20...  Training Step: 431...  Training loss: 2.0178...  6.2933 sec/batch
# Epoch: 3/20...  Training Step: 432...  Training loss: 2.0224...  6.2890 sec/batch
# Epoch: 3/20...  Training Step: 433...  Training loss: 2.0151...  6.2649 sec/batch
# Epoch: 3/20...  Training Step: 434...  Training loss: 1.9896...  6.4170 sec/batch
# Epoch: 3/20...  Training Step: 435...  Training loss: 1.9795...  6.4463 sec/batch
# Epoch: 3/20...  Training Step: 436...  Training loss: 1.9951...  6.3994 sec/batch
# Epoch: 3/20...  Training Step: 437...  Training loss: 2.0017...  6.4095 sec/batch
# Epoch: 3/20...  Training Step: 438...  Training loss: 2.0261...  6.2782 sec/batch
# Epoch: 3/20...  Training Step: 439...  Training loss: 2.0005...  6.2816 sec/batch
# Epoch: 3/20...  Training Step: 440...  Training loss: 1.9905...  6.2811 sec/batch
# Epoch: 3/20...  Training Step: 441...  Training loss: 2.0227...  6.3580 sec/batch
# Epoch: 3/20...  Training Step: 442...  Training loss: 1.9665...  6.5088 sec/batch
# Epoch: 3/20...  Training Step: 443...  Training loss: 2.0220...  6.2807 sec/batch
# Epoch: 3/20...  Training Step: 444...  Training loss: 1.9896...  6.3027 sec/batch
# Epoch: 3/20...  Training Step: 445...  Training loss: 2.0052...  6.2878 sec/batch
# Epoch: 3/20...  Training Step: 446...  Training loss: 2.0488...  6.2939 sec/batch
# Epoch: 3/20...  Training Step: 447...  Training loss: 1.9749...  6.2826 sec/batch
# Epoch: 3/20...  Training Step: 448...  Training loss: 2.0517...  6.2694 sec/batch
# Epoch: 3/20...  Training Step: 449...  Training loss: 1.9931...  6.3541 sec/batch
# Epoch: 3/20...  Training Step: 450...  Training loss: 1.9995...  6.3400 sec/batch
# Epoch: 3/20...  Training Step: 451...  Training loss: 1.9898...  6.2645 sec/batch
# Epoch: 3/20...  Training Step: 452...  Training loss: 2.0072...  6.2540 sec/batch
# Epoch: 3/20...  Training Step: 453...  Training loss: 2.0121...  6.3424 sec/batch
# Epoch: 3/20...  Training Step: 454...  Training loss: 1.9929...  6.2988 sec/batch
# Epoch: 3/20...  Training Step: 455...  Training loss: 1.9774...  6.2635 sec/batch
# Epoch: 3/20...  Training Step: 456...  Training loss: 2.0334...  6.2952 sec/batch
# Epoch: 3/20...  Training Step: 457...  Training loss: 1.9889...  6.3508 sec/batch
# Epoch: 3/20...  Training Step: 458...  Training loss: 2.0276...  6.3758 sec/batch
# Epoch: 3/20...  Training Step: 459...  Training loss: 2.0289...  6.2963 sec/batch
# Epoch: 3/20...  Training Step: 460...  Training loss: 2.0049...  6.2918 sec/batch
# Epoch: 3/20...  Training Step: 461...  Training loss: 1.9854...  6.2953 sec/batch
# Epoch: 3/20...  Training Step: 462...  Training loss: 2.0119...  6.2664 sec/batch
# Epoch: 3/20...  Training Step: 463...  Training loss: 2.0054...  6.2826 sec/batch
# Epoch: 3/20...  Training Step: 464...  Training loss: 1.9644...  6.3874 sec/batch
# Epoch: 3/20...  Training Step: 465...  Training loss: 1.9744...  6.3856 sec/batch
# Epoch: 3/20...  Training Step: 466...  Training loss: 1.9834...  6.2782 sec/batch
# Epoch: 3/20...  Training Step: 467...  Training loss: 2.0258...  6.2825 sec/batch
# Epoch: 3/20...  Training Step: 468...  Training loss: 1.9887...  6.2698 sec/batch
# Epoch: 3/20...  Training Step: 469...  Training loss: 2.0068...  6.3037 sec/batch
# Epoch: 3/20...  Training Step: 470...  Training loss: 1.9645...  6.2885 sec/batch
# Epoch: 3/20...  Training Step: 471...  Training loss: 1.9802...  6.2633 sec/batch
# Epoch: 3/20...  Training Step: 472...  Training loss: 2.0093...  6.4474 sec/batch
# Epoch: 3/20...  Training Step: 473...  Training loss: 1.9758...  6.3882 sec/batch
# Epoch: 3/20...  Training Step: 474...  Training loss: 1.9813...  6.2795 sec/batch
# Epoch: 3/20...  Training Step: 475...  Training loss: 1.9425...  6.2708 sec/batch
# Epoch: 3/20...  Training Step: 476...  Training loss: 1.9702...  6.2836 sec/batch
# Epoch: 3/20...  Training Step: 477...  Training loss: 1.9350...  6.2738 sec/batch
# Epoch: 3/20...  Training Step: 478...  Training loss: 1.9822...  6.4149 sec/batch
# Epoch: 3/20...  Training Step: 479...  Training loss: 1.9408...  6.2767 sec/batch
# Epoch: 3/20...  Training Step: 480...  Training loss: 1.9620...  6.3287 sec/batch
# Epoch: 3/20...  Training Step: 481...  Training loss: 1.9334...  6.3846 sec/batch
# Epoch: 3/20...  Training Step: 482...  Training loss: 1.9469...  6.2942 sec/batch
# Epoch: 3/20...  Training Step: 483...  Training loss: 1.9616...  6.2831 sec/batch
# Epoch: 3/20...  Training Step: 484...  Training loss: 1.9426...  6.5112 sec/batch
# Epoch: 3/20...  Training Step: 485...  Training loss: 1.9349...  6.2869 sec/batch
# Epoch: 3/20...  Training Step: 486...  Training loss: 1.9762...  6.2723 sec/batch
# Epoch: 3/20...  Training Step: 487...  Training loss: 1.9374...  6.3523 sec/batch
# Epoch: 3/20...  Training Step: 488...  Training loss: 1.9551...  6.3457 sec/batch
# Epoch: 3/20...  Training Step: 489...  Training loss: 1.9308...  6.2909 sec/batch
# Epoch: 3/20...  Training Step: 490...  Training loss: 1.9390...  6.2669 sec/batch
# Epoch: 3/20...  Training Step: 491...  Training loss: 1.9312...  6.3253 sec/batch
# Epoch: 3/20...  Training Step: 492...  Training loss: 1.9488...  6.2918 sec/batch
# Epoch: 3/20...  Training Step: 493...  Training loss: 1.9348...  6.2753 sec/batch
# Epoch: 3/20...  Training Step: 494...  Training loss: 1.9229...  6.2610 sec/batch
# Epoch: 3/20...  Training Step: 495...  Training loss: 1.9290...  6.3478 sec/batch
# Epoch: 3/20...  Training Step: 496...  Training loss: 1.9114...  6.3478 sec/batch
# Epoch: 3/20...  Training Step: 497...  Training loss: 1.9505...  6.2782 sec/batch
# Epoch: 3/20...  Training Step: 498...  Training loss: 1.9417...  6.2497 sec/batch
# Epoch: 3/20...  Training Step: 499...  Training loss: 1.9342...  6.2737 sec/batch
# Epoch: 3/20...  Training Step: 500...  Training loss: 1.9286...  6.2608 sec/batch
# Epoch: 3/20...  Training Step: 501...  Training loss: 1.9223...  6.2674 sec/batch
# Epoch: 3/20...  Training Step: 502...  Training loss: 1.9292...  6.3081 sec/batch
# Epoch: 3/20...  Training Step: 503...  Training loss: 1.9307...  6.3361 sec/batch
# Epoch: 3/20...  Training Step: 504...  Training loss: 1.9411...  6.3757 sec/batch
# Epoch: 3/20...  Training Step: 505...  Training loss: 1.9494...  6.2585 sec/batch
# Epoch: 3/20...  Training Step: 506...  Training loss: 1.9517...  6.2904 sec/batch
# Epoch: 3/20...  Training Step: 507...  Training loss: 1.9405...  6.2850 sec/batch
# Epoch: 3/20...  Training Step: 508...  Training loss: 1.9277...  6.2875 sec/batch
# Epoch: 3/20...  Training Step: 509...  Training loss: 1.9288...  6.2545 sec/batch
# Epoch: 3/20...  Training Step: 510...  Training loss: 1.9225...  6.3773 sec/batch
# Epoch: 3/20...  Training Step: 511...  Training loss: 1.9115...  6.3905 sec/batch
# Epoch: 3/20...  Training Step: 512...  Training loss: 1.9002...  6.2447 sec/batch
# Epoch: 3/20...  Training Step: 513...  Training loss: 1.9317...  6.2728 sec/batch
# Epoch: 3/20...  Training Step: 514...  Training loss: 1.9211...  6.2713 sec/batch
# Epoch: 3/20...  Training Step: 515...  Training loss: 1.9301...  6.3773 sec/batch
# Epoch: 3/20...  Training Step: 516...  Training loss: 1.9279...  6.3223 sec/batch
# Epoch: 3/20...  Training Step: 517...  Training loss: 1.9430...  6.2512 sec/batch
# Epoch: 3/20...  Training Step: 518...  Training loss: 1.8951...  6.3591 sec/batch
# Epoch: 3/20...  Training Step: 519...  Training loss: 1.9120...  6.3513 sec/batch
# Epoch: 3/20...  Training Step: 520...  Training loss: 1.9472...  6.2917 sec/batch
# Epoch: 3/20...  Training Step: 521...  Training loss: 1.9219...  6.2767 sec/batch
# Epoch: 3/20...  Training Step: 522...  Training loss: 1.8681...  6.2718 sec/batch
# Epoch: 3/20...  Training Step: 523...  Training loss: 1.9352...  6.2654 sec/batch
# Epoch: 3/20...  Training Step: 524...  Training loss: 1.9342...  6.2481 sec/batch
# Epoch: 3/20...  Training Step: 525...  Training loss: 1.9221...  6.2772 sec/batch
# Epoch: 3/20...  Training Step: 526...  Training loss: 1.9200...  6.3164 sec/batch
# Epoch: 3/20...  Training Step: 527...  Training loss: 1.8882...  6.3395 sec/batch
# Epoch: 3/20...  Training Step: 528...  Training loss: 1.8792...  6.2496 sec/batch
# Epoch: 3/20...  Training Step: 529...  Training loss: 1.9275...  6.3297 sec/batch
# Epoch: 3/20...  Training Step: 530...  Training loss: 1.9261...  6.3508 sec/batch
# Epoch: 3/20...  Training Step: 531...  Training loss: 1.9169...  6.3968 sec/batch
# Epoch: 3/20...  Training Step: 532...  Training loss: 1.9282...  6.4131 sec/batch
# Epoch: 3/20...  Training Step: 533...  Training loss: 1.9197...  6.3262 sec/batch
# Epoch: 3/20...  Training Step: 534...  Training loss: 1.9141...  6.3963 sec/batch
# Epoch: 3/20...  Training Step: 535...  Training loss: 1.9527...  6.2821 sec/batch
# Epoch: 3/20...  Training Step: 536...  Training loss: 1.9008...  6.3449 sec/batch
# Epoch: 3/20...  Training Step: 537...  Training loss: 1.9390...  6.2801 sec/batch
# Epoch: 3/20...  Training Step: 538...  Training loss: 1.9137...  6.3055 sec/batch
# Epoch: 3/20...  Training Step: 539...  Training loss: 1.9103...  6.2801 sec/batch
# Epoch: 3/20...  Training Step: 540...  Training loss: 1.9075...  6.2919 sec/batch
# Epoch: 3/20...  Training Step: 541...  Training loss: 1.8996...  6.3484 sec/batch
# Epoch: 3/20...  Training Step: 542...  Training loss: 1.9083...  6.3870 sec/batch
# Epoch: 3/20...  Training Step: 543...  Training loss: 1.9336...  6.2993 sec/batch
# Epoch: 3/20...  Training Step: 544...  Training loss: 1.9538...  6.3008 sec/batch
# Epoch: 3/20...  Training Step: 545...  Training loss: 1.9111...  6.2858 sec/batch
# Epoch: 3/20...  Training Step: 546...  Training loss: 1.8962...  6.2944 sec/batch
# Epoch: 3/20...  Training Step: 547...  Training loss: 1.8944...  6.2418 sec/batch
# Epoch: 3/20...  Training Step: 548...  Training loss: 1.9430...  6.3155 sec/batch
# Epoch: 3/20...  Training Step: 549...  Training loss: 1.9256...  6.3077 sec/batch
# Epoch: 3/20...  Training Step: 550...  Training loss: 1.9121...  6.3952 sec/batch
# Epoch: 3/20...  Training Step: 551...  Training loss: 1.8989...  6.2708 sec/batch
# Epoch: 3/20...  Training Step: 552...  Training loss: 1.8924...  6.2571 sec/batch
# Epoch: 3/20...  Training Step: 553...  Training loss: 1.9106...  6.2773 sec/batch
# Epoch: 3/20...  Training Step: 554...  Training loss: 1.8905...  6.2657 sec/batch
# Epoch: 3/20...  Training Step: 555...  Training loss: 1.8643...  6.2659 sec/batch
# Epoch: 3/20...  Training Step: 556...  Training loss: 1.9245...  6.3606 sec/batch
# Epoch: 3/20...  Training Step: 557...  Training loss: 1.9286...  6.3772 sec/batch
# Epoch: 3/20...  Training Step: 558...  Training loss: 1.8958...  6.2708 sec/batch
# Epoch: 3/20...  Training Step: 559...  Training loss: 1.9119...  6.2845 sec/batch
# Epoch: 3/20...  Training Step: 560...  Training loss: 1.9016...  6.2890 sec/batch
# Epoch: 3/20...  Training Step: 561...  Training loss: 1.8896...  6.2644 sec/batch
# Epoch: 3/20...  Training Step: 562...  Training loss: 1.8835...  6.2883 sec/batch
# Epoch: 3/20...  Training Step: 563...  Training loss: 1.8985...  6.2600 sec/batch
# Epoch: 3/20...  Training Step: 564...  Training loss: 1.9458...  6.3606 sec/batch
# Epoch: 3/20...  Training Step: 565...  Training loss: 1.8733...  6.3611 sec/batch
# Epoch: 3/20...  Training Step: 566...  Training loss: 1.8836...  6.2731 sec/batch
# Epoch: 3/20...  Training Step: 567...  Training loss: 1.8623...  6.3164 sec/batch
# Epoch: 3/20...  Training Step: 568...  Training loss: 1.8792...  6.3287 sec/batch
# Epoch: 3/20...  Training Step: 569...  Training loss: 1.9076...  6.2845 sec/batch
# Epoch: 3/20...  Training Step: 570...  Training loss: 1.8996...  6.2859 sec/batch
# Epoch: 3/20...  Training Step: 571...  Training loss: 1.8959...  6.2684 sec/batch
# Epoch: 3/20...  Training Step: 572...  Training loss: 1.8872...  6.2752 sec/batch
# Epoch: 3/20...  Training Step: 573...  Training loss: 1.8643...  6.2772 sec/batch
# Epoch: 3/20...  Training Step: 574...  Training loss: 1.8917...  6.2648 sec/batch
# Epoch: 3/20...  Training Step: 575...  Training loss: 1.8640...  6.2944 sec/batch
# Epoch: 3/20...  Training Step: 576...  Training loss: 1.8442...  6.2586 sec/batch
# Epoch: 3/20...  Training Step: 577...  Training loss: 1.8568...  6.2634 sec/batch
# Epoch: 3/20...  Training Step: 578...  Training loss: 1.8770...  6.3354 sec/batch
# Epoch: 3/20...  Training Step: 579...  Training loss: 1.8776...  6.6570 sec/batch
# Epoch: 3/20...  Training Step: 580...  Training loss: 1.8974...  6.3781 sec/batch
# Epoch: 3/20...  Training Step: 581...  Training loss: 1.8660...  6.3027 sec/batch
# Epoch: 3/20...  Training Step: 582...  Training loss: 1.8618...  6.2904 sec/batch
# ...
# Epoch: 20/20...  Training Step: 3771...  Training loss: 1.2252...  6.2599 sec/batch
# Epoch: 20/20...  Training Step: 3772...  Training loss: 1.2113...  6.2826 sec/batch
# Epoch: 20/20...  Training Step: 3773...  Training loss: 1.2200...  6.3135 sec/batch
# Epoch: 20/20...  Training Step: 3774...  Training loss: 1.2201...  6.3542 sec/batch
# Epoch: 20/20...  Training Step: 3775...  Training loss: 1.2284...  6.2511 sec/batch
# Epoch: 20/20...  Training Step: 3776...  Training loss: 1.2344...  6.2630 sec/batch
# Epoch: 20/20...  Training Step: 3777...  Training loss: 1.2046...  6.2723 sec/batch
# Epoch: 20/20...  Training Step: 3778...  Training loss: 1.2071...  6.2561 sec/batch
# Epoch: 20/20...  Training Step: 3779...  Training loss: 1.2368...  6.3492 sec/batch
# Epoch: 20/20...  Training Step: 3780...  Training loss: 1.2424...  6.2787 sec/batch
# Epoch: 20/20...  Training Step: 3781...  Training loss: 1.2196...  6.3420 sec/batch
# Epoch: 20/20...  Training Step: 3782...  Training loss: 1.2570...  6.3454 sec/batch
# Epoch: 20/20...  Training Step: 3783...  Training loss: 1.2196...  6.2594 sec/batch
# Epoch: 20/20...  Training Step: 3784...  Training loss: 1.2348...  6.2728 sec/batch
# Epoch: 20/20...  Training Step: 3785...  Training loss: 1.2152...  6.2669 sec/batch
# Epoch: 20/20...  Training Step: 3786...  Training loss: 1.2351...  6.2600 sec/batch
# Epoch: 20/20...  Training Step: 3787...  Training loss: 1.2190...  6.2551 sec/batch
# Epoch: 20/20...  Training Step: 3788...  Training loss: 1.1869...  6.2711 sec/batch
# Epoch: 20/20...  Training Step: 3789...  Training loss: 1.1956...  6.3307 sec/batch
# Epoch: 20/20...  Training Step: 3790...  Training loss: 1.2364...  6.3287 sec/batch
# Epoch: 20/20...  Training Step: 3791...  Training loss: 1.2232...  6.3093 sec/batch
# Epoch: 20/20...  Training Step: 3792...  Training loss: 1.2364...  6.2764 sec/batch
# Epoch: 20/20...  Training Step: 3793...  Training loss: 1.2036...  6.2816 sec/batch
# Epoch: 20/20...  Training Step: 3794...  Training loss: 1.1873...  6.2615 sec/batch
# Epoch: 20/20...  Training Step: 3795...  Training loss: 1.2225...  6.2773 sec/batch
# Epoch: 20/20...  Training Step: 3796...  Training loss: 1.2259...  6.3594 sec/batch
# Epoch: 20/20...  Training Step: 3797...  Training loss: 1.2049...  6.3577 sec/batch
# Epoch: 20/20...  Training Step: 3798...  Training loss: 1.2275...  6.3655 sec/batch
# Epoch: 20/20...  Training Step: 3799...  Training loss: 1.1986...  6.2898 sec/batch
# Epoch: 20/20...  Training Step: 3800...  Training loss: 1.1795...  6.2546 sec/batch
# Epoch: 20/20...  Training Step: 3801...  Training loss: 1.1828...  6.2983 sec/batch
# Epoch: 20/20...  Training Step: 3802...  Training loss: 1.2092...  6.2760 sec/batch
# Epoch: 20/20...  Training Step: 3803...  Training loss: 1.1976...  6.2571 sec/batch
# Epoch: 20/20...  Training Step: 3804...  Training loss: 1.2624...  6.3385 sec/batch
# Epoch: 20/20...  Training Step: 3805...  Training loss: 1.2186...  6.3586 sec/batch
# Epoch: 20/20...  Training Step: 3806...  Training loss: 1.2048...  6.2795 sec/batch
# Epoch: 20/20...  Training Step: 3807...  Training loss: 1.2257...  6.2811 sec/batch
# Epoch: 20/20...  Training Step: 3808...  Training loss: 1.2028...  6.2487 sec/batch
# Epoch: 20/20...  Training Step: 3809...  Training loss: 1.2114...  6.5347 sec/batch
# Epoch: 20/20...  Training Step: 3810...  Training loss: 1.2100...  6.2640 sec/batch
# Epoch: 20/20...  Training Step: 3811...  Training loss: 1.2206...  6.2468 sec/batch
# Epoch: 20/20...  Training Step: 3812...  Training loss: 1.2464...  6.3169 sec/batch
# Epoch: 20/20...  Training Step: 3813...  Training loss: 1.1958...  6.3806 sec/batch
# Epoch: 20/20...  Training Step: 3814...  Training loss: 1.2666...  6.2502 sec/batch
# Epoch: 20/20...  Training Step: 3815...  Training loss: 1.2335...  6.2679 sec/batch
# Epoch: 20/20...  Training Step: 3816...  Training loss: 1.2280...  6.3076 sec/batch
# Epoch: 20/20...  Training Step: 3817...  Training loss: 1.2136...  6.3349 sec/batch
# Epoch: 20/20...  Training Step: 3818...  Training loss: 1.2233...  6.2634 sec/batch
# Epoch: 20/20...  Training Step: 3819...  Training loss: 1.2269...  6.3229 sec/batch
# Epoch: 20/20...  Training Step: 3820...  Training loss: 1.2176...  6.3773 sec/batch
# Epoch: 20/20...  Training Step: 3821...  Training loss: 1.1996...  6.2830 sec/batch
# Epoch: 20/20...  Training Step: 3822...  Training loss: 1.2599...  6.2890 sec/batch
# Epoch: 20/20...  Training Step: 3823...  Training loss: 1.2292...  6.2826 sec/batch
# Epoch: 20/20...  Training Step: 3824...  Training loss: 1.2608...  6.2924 sec/batch
# Epoch: 20/20...  Training Step: 3825...  Training loss: 1.2437...  6.2677 sec/batch
# Epoch: 20/20...  Training Step: 3826...  Training loss: 1.2231...  6.2738 sec/batch
# Epoch: 20/20...  Training Step: 3827...  Training loss: 1.2215...  6.3346 sec/batch
# Epoch: 20/20...  Training Step: 3828...  Training loss: 1.2253...  6.3735 sec/batch
# Epoch: 20/20...  Training Step: 3829...  Training loss: 1.2532...  6.2573 sec/batch
# Epoch: 20/20...  Training Step: 3830...  Training loss: 1.2035...  6.2605 sec/batch
# Epoch: 20/20...  Training Step: 3831...  Training loss: 1.2260...  6.2679 sec/batch
# Epoch: 20/20...  Training Step: 3832...  Training loss: 1.2070...  6.2489 sec/batch
# Epoch: 20/20...  Training Step: 3833...  Training loss: 1.2661...  6.2613 sec/batch
# Epoch: 20/20...  Training Step: 3834...  Training loss: 1.2325...  6.3091 sec/batch
# Epoch: 20/20...  Training Step: 3835...  Training loss: 1.2570...  6.2664 sec/batch
# Epoch: 20/20...  Training Step: 3836...  Training loss: 1.2052...  6.3523 sec/batch
# Epoch: 20/20...  Training Step: 3837...  Training loss: 1.2125...  6.2712 sec/batch
# Epoch: 20/20...  Training Step: 3838...  Training loss: 1.2296...  6.2546 sec/batch
# Epoch: 20/20...  Training Step: 3839...  Training loss: 1.2236...  6.9831 sec/batch
# Epoch: 20/20...  Training Step: 3840...  Training loss: 1.2091...  7.2009 sec/batch
# Epoch: 20/20...  Training Step: 3841...  Training loss: 1.1828...  6.5893 sec/batch
# Epoch: 20/20...  Training Step: 3842...  Training loss: 1.2194...  7.1097 sec/batch
# Epoch: 20/20...  Training Step: 3843...  Training loss: 1.1890...  6.4385 sec/batch
# Epoch: 20/20...  Training Step: 3844...  Training loss: 1.2111...  6.3155 sec/batch
# Epoch: 20/20...  Training Step: 3845...  Training loss: 1.1919...  6.2585 sec/batch
# Epoch: 20/20...  Training Step: 3846...  Training loss: 1.2184...  6.3038 sec/batch
# Epoch: 20/20...  Training Step: 3847...  Training loss: 1.2006...  6.2990 sec/batch
# Epoch: 20/20...  Training Step: 3848...  Training loss: 1.2171...  6.2826 sec/batch
# Epoch: 20/20...  Training Step: 3849...  Training loss: 1.1843...  6.2865 sec/batch
# Epoch: 20/20...  Training Step: 3850...  Training loss: 1.2035...  6.3698 sec/batch
# Epoch: 20/20...  Training Step: 3851...  Training loss: 1.1845...  6.4749 sec/batch
# Epoch: 20/20...  Training Step: 3852...  Training loss: 1.2223...  6.2688 sec/batch
# Epoch: 20/20...  Training Step: 3853...  Training loss: 1.1938...  6.2414 sec/batch
# Epoch: 20/20...  Training Step: 3854...  Training loss: 1.1986...  6.3512 sec/batch
# Epoch: 20/20...  Training Step: 3855...  Training loss: 1.1950...  6.2719 sec/batch
# Epoch: 20/20...  Training Step: 3856...  Training loss: 1.1918...  6.4062 sec/batch
# Epoch: 20/20...  Training Step: 3857...  Training loss: 1.2029...  6.4473 sec/batch
# Epoch: 20/20...  Training Step: 3858...  Training loss: 1.2300...  6.3081 sec/batch
# Epoch: 20/20...  Training Step: 3859...  Training loss: 1.2160...  6.3670 sec/batch
# Epoch: 20/20...  Training Step: 3860...  Training loss: 1.1790...  6.2664 sec/batch
# Epoch: 20/20...  Training Step: 3861...  Training loss: 1.1972...  6.2535 sec/batch
# Epoch: 20/20...  Training Step: 3862...  Training loss: 1.2052...  6.2492 sec/batch
# Epoch: 20/20...  Training Step: 3863...  Training loss: 1.2133...  6.2536 sec/batch
# Epoch: 20/20...  Training Step: 3864...  Training loss: 1.2048...  6.2605 sec/batch
# Epoch: 20/20...  Training Step: 3865...  Training loss: 1.2202...  6.3091 sec/batch
# Epoch: 20/20...  Training Step: 3866...  Training loss: 1.2051...  6.3777 sec/batch
# Epoch: 20/20...  Training Step: 3867...  Training loss: 1.2117...  6.2595 sec/batch
# Epoch: 20/20...  Training Step: 3868...  Training loss: 1.2176...  6.2468 sec/batch
# Epoch: 20/20...  Training Step: 3869...  Training loss: 1.2174...  6.2566 sec/batch
# Epoch: 20/20...  Training Step: 3870...  Training loss: 1.2161...  6.2093 sec/batch
# Epoch: 20/20...  Training Step: 3871...  Training loss: 1.2015...  6.2600 sec/batch
# Epoch: 20/20...  Training Step: 3872...  Training loss: 1.2301...  6.2292 sec/batch
# Epoch: 20/20...  Training Step: 3873...  Training loss: 1.1981...  6.3900 sec/batch
# Epoch: 20/20...  Training Step: 3874...  Training loss: 1.2220...  6.3827 sec/batch
# Epoch: 20/20...  Training Step: 3875...  Training loss: 1.2185...  6.2821 sec/batch
# Epoch: 20/20...  Training Step: 3876...  Training loss: 1.2133...  6.2433 sec/batch
# Epoch: 20/20...  Training Step: 3877...  Training loss: 1.1905...  6.2586 sec/batch
# Epoch: 20/20...  Training Step: 3878...  Training loss: 1.1865...  6.2684 sec/batch
# Epoch: 20/20...  Training Step: 3879...  Training loss: 1.2339...  6.2515 sec/batch
# Epoch: 20/20...  Training Step: 3880...  Training loss: 1.2242...  6.2625 sec/batch
# Epoch: 20/20...  Training Step: 3881...  Training loss: 1.2151...  6.3208 sec/batch
# Epoch: 20/20...  Training Step: 3882...  Training loss: 1.2176...  6.3547 sec/batch
# Epoch: 20/20...  Training Step: 3883...  Training loss: 1.2148...  6.2525 sec/batch
# Epoch: 20/20...  Training Step: 3884...  Training loss: 1.1874...  6.2438 sec/batch
# Epoch: 20/20...  Training Step: 3885...  Training loss: 1.1784...  6.2703 sec/batch
# Epoch: 20/20...  Training Step: 3886...  Training loss: 1.2182...  6.2507 sec/batch
# Epoch: 20/20...  Training Step: 3887...  Training loss: 1.1962...  6.2768 sec/batch
# Epoch: 20/20...  Training Step: 3888...  Training loss: 1.1790...  6.3216 sec/batch
# Epoch: 20/20...  Training Step: 3889...  Training loss: 1.2185...  6.3434 sec/batch
# Epoch: 20/20...  Training Step: 3890...  Training loss: 1.2134...  6.2855 sec/batch
# Epoch: 20/20...  Training Step: 3891...  Training loss: 1.1926...  6.2388 sec/batch
# Epoch: 20/20...  Training Step: 3892...  Training loss: 1.1733...  6.3375 sec/batch
# Epoch: 20/20...  Training Step: 3893...  Training loss: 1.1730...  6.2792 sec/batch
# Epoch: 20/20...  Training Step: 3894...  Training loss: 1.1983...  6.2370 sec/batch
# Epoch: 20/20...  Training Step: 3895...  Training loss: 1.2385...  6.2414 sec/batch
# Epoch: 20/20...  Training Step: 3896...  Training loss: 1.2227...  6.3448 sec/batch
# Epoch: 20/20...  Training Step: 3897...  Training loss: 1.2258...  6.3508 sec/batch
# Epoch: 20/20...  Training Step: 3898...  Training loss: 1.2170...  6.3228 sec/batch
# Epoch: 20/20...  Training Step: 3899...  Training loss: 1.2382...  6.2830 sec/batch
# Epoch: 20/20...  Training Step: 3900...  Training loss: 1.2274...  6.2525 sec/batch
# Epoch: 20/20...  Training Step: 3901...  Training loss: 1.2107...  6.2252 sec/batch
# Epoch: 20/20...  Training Step: 3902...  Training loss: 1.2309...  6.2640 sec/batch
# Epoch: 20/20...  Training Step: 3903...  Training loss: 1.2592...  6.2845 sec/batch
# Epoch: 20/20...  Training Step: 3904...  Training loss: 1.2383...  6.4973 sec/batch
# Epoch: 20/20...  Training Step: 3905...  Training loss: 1.2099...  6.3351 sec/batch
# Epoch: 20/20...  Training Step: 3906...  Training loss: 1.2453...  6.2733 sec/batch
# Epoch: 20/20...  Training Step: 3907...  Training loss: 1.1996...  6.2654 sec/batch
# Epoch: 20/20...  Training Step: 3908...  Training loss: 1.2388...  6.2815 sec/batch
# Epoch: 20/20...  Training Step: 3909...  Training loss: 1.2250...  6.3003 sec/batch
# Epoch: 20/20...  Training Step: 3910...  Training loss: 1.2553...  6.2797 sec/batch
# Epoch: 20/20...  Training Step: 3911...  Training loss: 1.2422...  6.3963 sec/batch
# Epoch: 20/20...  Training Step: 3912...  Training loss: 1.2178...  6.3930 sec/batch
# Epoch: 20/20...  Training Step: 3913...  Training loss: 1.1844...  6.2698 sec/batch
# Epoch: 20/20...  Training Step: 3914...  Training loss: 1.1943...  6.2510 sec/batch
# Epoch: 20/20...  Training Step: 3915...  Training loss: 1.2271...  6.2520 sec/batch
# Epoch: 20/20...  Training Step: 3916...  Training loss: 1.2130...  6.2502 sec/batch
# Epoch: 20/20...  Training Step: 3917...  Training loss: 1.2087...  6.2492 sec/batch
# Epoch: 20/20...  Training Step: 3918...  Training loss: 1.2074...  6.2669 sec/batch
# Epoch: 20/20...  Training Step: 3919...  Training loss: 1.2163...  6.3533 sec/batch
# Epoch: 20/20...  Training Step: 3920...  Training loss: 1.2120...  6.3266 sec/batch
# Epoch: 20/20...  Training Step: 3921...  Training loss: 1.1886...  6.2708 sec/batch
# Epoch: 20/20...  Training Step: 3922...  Training loss: 1.2496...  6.2792 sec/batch
# Epoch: 20/20...  Training Step: 3923...  Training loss: 1.2351...  6.2684 sec/batch
# Epoch: 20/20...  Training Step: 3924...  Training loss: 1.2231...  6.2829 sec/batch
# Epoch: 20/20...  Training Step: 3925...  Training loss: 1.2158...  6.2654 sec/batch
# Epoch: 20/20...  Training Step: 3926...  Training loss: 1.2216...  6.2644 sec/batch
# Epoch: 20/20...  Training Step: 3927...  Training loss: 1.2206...  6.2590 sec/batch
# Epoch: 20/20...  Training Step: 3928...  Training loss: 1.2062...  6.2556 sec/batch
# Epoch: 20/20...  Training Step: 3929...  Training loss: 1.2367...  6.2643 sec/batch
# Epoch: 20/20...  Training Step: 3930...  Training loss: 1.2667...  6.3361 sec/batch
# Epoch: 20/20...  Training Step: 3931...  Training loss: 1.2248...  6.3037 sec/batch
# Epoch: 20/20...  Training Step: 3932...  Training loss: 1.2231...  6.2688 sec/batch
# Epoch: 20/20...  Training Step: 3933...  Training loss: 1.2048...  6.2456 sec/batch
# Epoch: 20/20...  Training Step: 3934...  Training loss: 1.2093...  6.3223 sec/batch
# Epoch: 20/20...  Training Step: 3935...  Training loss: 1.2482...  6.3400 sec/batch
# Epoch: 20/20...  Training Step: 3936...  Training loss: 1.2148...  6.2620 sec/batch
# Epoch: 20/20...  Training Step: 3937...  Training loss: 1.2125...  6.2554 sec/batch
# Epoch: 20/20...  Training Step: 3938...  Training loss: 1.1998...  6.2669 sec/batch
# Epoch: 20/20...  Training Step: 3939...  Training loss: 1.2159...  6.2767 sec/batch
# Epoch: 20/20...  Training Step: 3940...  Training loss: 1.2568...  6.2836 sec/batch
# Epoch: 20/20...  Training Step: 3941...  Training loss: 1.2106...  6.2614 sec/batch
# Epoch: 20/20...  Training Step: 3942...  Training loss: 1.1991...  6.3429 sec/batch
# Epoch: 20/20...  Training Step: 3943...  Training loss: 1.2028...  6.3508 sec/batch
# Epoch: 20/20...  Training Step: 3944...  Training loss: 1.2286...  6.2458 sec/batch
# Epoch: 20/20...  Training Step: 3945...  Training loss: 1.2127...  6.2707 sec/batch
# Epoch: 20/20...  Training Step: 3946...  Training loss: 1.2052...  6.2635 sec/batch
# Epoch: 20/20...  Training Step: 3947...  Training loss: 1.2002...  6.2556 sec/batch
# Epoch: 20/20...  Training Step: 3948...  Training loss: 1.1842...  6.3012 sec/batch
# Epoch: 20/20...  Training Step: 3949...  Training loss: 1.2347...  6.2555 sec/batch
# Epoch: 20/20...  Training Step: 3950...  Training loss: 1.2091...  6.3846 sec/batch
# Epoch: 20/20...  Training Step: 3951...  Training loss: 1.2104...  6.4033 sec/batch
# Epoch: 20/20...  Training Step: 3952...  Training loss: 1.2194...  6.5170 sec/batch
# Epoch: 20/20...  Training Step: 3953...  Training loss: 1.1961...  6.3803 sec/batch
# Epoch: 20/20...  Training Step: 3954...  Training loss: 1.1966...  6.2551 sec/batch
# Epoch: 20/20...  Training Step: 3955...  Training loss: 1.2128...  6.2615 sec/batch
# Epoch: 20/20...  Training Step: 3956...  Training loss: 1.1933...  6.2466 sec/batch
# Epoch: 20/20...  Training Step: 3957...  Training loss: 1.1810...  6.3253 sec/batch
# Epoch: 20/20...  Training Step: 3958...  Training loss: 1.2178...  6.3969 sec/batch
# Epoch: 20/20...  Training Step: 3959...  Training loss: 1.2102...  6.2542 sec/batch
# Epoch: 20/20...  Training Step: 3960...  Training loss: 1.2050...  6.2559 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints\\i3960_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i1000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i1200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i1400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i1600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i1800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i2000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i2200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i2400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i2600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i2800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints\\i3960_l512.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints\\i3960_l512.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\i3960_l512.ckpt
# Farent with his
# subject, as though he was not so learned when he had a still,
# tealing the carriage.
#
# She was so such a particularly disputed. And three honose heart was
# instintteness, but at the same position to his brother's colonel,
# and was nairlessly and wondering him over that he cleared to some
# sort, and she should have long been been but herself, and there was
# nothing to tell her wearieds in his forming, but had been so long when the
# subject to her table, and that she had seen the paper of his own cares the
# people.
#
# "I don't say something all about it."
#
# And this always should not take her father.
#
# "This more and you think.,." he said.
#
# "To my hands, what he's saying to her? The contest in hin a supper for me,
# too much their father or much a marsh." She was not himself, because he
# had too, that he had been driving up to the same things at once.
#
# "I should have seen your face with the way. But I won't those thoughts
# to her many talk, that I can't have an expression of myself about them,
# all--all all this it had been thinking about it."
#
# "We are not all was too; but he could have told him if you do not
# strengthered her to have their proculer talk of the second part of it."
#
# "You."
#
# Anna was sitting to her husband. "I said there's a mild," she thought, "In
# the country, was the feeling of some solition, but husband who hast's
# seen an even," she asked her humiliate attention in which he was almost
# as a little, he walked away, and she stood that in his words.
#
# "Yes, I have so sort of sold of this simpligity, the state of a fat
# warms to the children, and I don't stay," said Vronsky.
#
# "Yes, but I should gave her such misince to think as it is all that..."
#
# "Well, what wonly if I'm not the same time of your same, I should have told
# you on the sort of the child who has so disturbed with the continual
# peasants, and he was tried. After distustive with the waiter with
# their carriage, to this servant and mere, there's no one in a creature
# of these words. They're not a matter in

# %% [markdown]
# **My version of TensorFlow is saving the check points in a diferent way. I`ll take a look on it in the future. But the RNN looks to be working**

# %% [markdown]
# [Andrej Karpathy's](https://www.youtube.com/watch?v=iX5V1WpxxkY) lecture on RNNs and LSTMs from CS231n <br>
# [A great blog post](http://colah.github.io/posts/2015-08-Understanding-LSTMs/) by Christopher Olah on how LSTMs work. <br>
# [Building an RNN](http://r2rt.com/recurrent-neural-networks-in-tensorflow-i.html) from the ground up, this is a little more advanced, but has an implementation in TensorFlow.
