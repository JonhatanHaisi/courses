# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5

word_counter = Counter(int_words)
total_words = len(int_words)

p_drop = { word: 1 - np.sqrt(threshold / (count/total_words)) for word, count in word_counter.items() }

train_words = [ word for word in int_words if random.random() < (1 - p_drop[word]) ] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    min_ix = max(idx - R, 0)
    max_ix = idx + R + 1
    
    return list(set(words[min_ix : idx] + words[idx + 1 : max_ix]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs') 
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\JONAT\Anaconda3\envs\tf-py3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# Já existe uma subpasta ou um arquivo checkpoints.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6719 0.4391 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6229 0.4349 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4909 0.4365 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5945 0.4338 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4955 0.4314 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5505 0.4308 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5489 0.4303 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5470 0.4378 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4490 0.4350 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4907 0.5198 sec/batch
# Nearest to history: homogenic, ditches, foote, willers, fic, authorization, sc, wikipedian,
# Nearest to the: retinue, into, interstate, renovated, troughton, heads, cholinesterase, anglo,
# Nearest to into: handle, hemicellulose, the, xli, corda, ancillary, summa, provenance,
# Nearest to however: granta, flavored, harrow, iteratively, smack, dorsey, sociologist, amoebozoa,
# Nearest to its: hurry, waterline, beckhams, further, twin, sidespin, appian, nebula,
# Nearest to has: hams, amputees, cockpits, omnipotence, repairs, crawling, restricting, impossible,
# Nearest to used: blenheim, blaise, reminded, remade, fatty, anemone, cabo, mycoplasma,
# Nearest to can: sfp, lse, at, intervocalic, clamshell, disarming, exhorted, dreamer,
# Nearest to heavy: akhmatova, matching, caron, autocephalous, sixxs, indri, scudetto, reciprocal,
# Nearest to operating: indicts, stele, pretense, sampler, coldcut, sterile, marianas, binitarianism,
# Nearest to active: lynched, branded, muselar, dvo, moved, aliphatic, voter, elements,
# Nearest to versions: eifel, ekron, imagining, reelected, repentant, deist, talionis, symbolise,
# Nearest to prince: fable, appleby, stater, sandtrout, annex, tightly, kee, fusing,
# Nearest to except: colonists, rosenzweig, initiations, trollh, paleontological, mrsi, skipping, scofield,
# Nearest to san: facundo, cuckoo, amon, rechristened, frisch, stalks, matrices, rival,
# Nearest to applied: espa, untrue, franchised, ban, jahn, pragmatically, murderer, engine,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4760 0.5348 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3632 0.5118 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3358 0.5169 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2664 0.4796 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1667 0.5459 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1859 0.5341 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1078 0.4601 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0812 0.4899 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0055 0.5305 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9852 0.5357 sec/batch
# Nearest to history: homogenic, foote, fic, constantly, sc, delivery, tradition, lines,
# Nearest to the: into, bill, training, renovated, custody, retinue, heads, instead,
# Nearest to into: handle, the, ancillary, criticism, hemicellulose, although, fleet, enough,
# Nearest to however: granta, flavored, level, harrow, iteratively, sociologist, smack, analysis,
# Nearest to its: further, hurry, twin, waterline, beckhams, answer, cheat, nebula,
# Nearest to has: impossible, restricting, hams, crawling, from, cockpits, placed, repairs,
# Nearest to used: value, blenheim, fatty, tide, awareness, blaise, additionally, pencil,
# Nearest to can: at, due, lse, extensively, sfp, meaningful, reference, disarming,
# Nearest to heavy: matching, akhmatova, had, late, east, dark, some, lend,
# Nearest to operating: indicts, sampler, stele, sterile, browser, pretense, coldcut, come,
# Nearest to active: branded, lynched, moved, elements, muselar, voter, glam, relevant,
# Nearest to versions: imagining, repentant, bulge, waits, eifel, painfully, shaikh, dissolve,
# Nearest to prince: fable, tightly, was, allows, appleby, stater, denver, annex,
# Nearest to except: colonists, attending, pointed, sizes, rosenzweig, which, duke, composition,
# Nearest to san: facundo, rival, cuckoo, amon, art, ripken, sum, rechristened,
# Nearest to applied: espa, ban, engine, untrue, dyed, innovation, objections, answer,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9418 0.5137 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8997 0.5035 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8802 0.4358 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8798 0.4507 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8180 0.4350 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8242 0.4327 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8058 0.4324 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8017 0.4311 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7947 0.4414 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7714 0.4330 sec/batch
# Nearest to history: homogenic, foote, sc, constantly, johan, authorization, fic, exhibits,
# Nearest to the: peculiar, renovated, into, bill, apocrypha, proceedings, flaws, markedly,
# Nearest to into: the, handle, ancillary, criticism, hemicellulose, summa, contraction, provenance,
# Nearest to however: granta, harrow, flavored, level, dorsey, sociologist, iteratively, walked,
# Nearest to its: hurry, twin, waterline, expedition, ceremony, further, nebula, cheat,
# Nearest to has: impossible, feeling, restricting, lungs, omnipotence, repairs, hams, crawling,
# Nearest to used: tide, blaise, blenheim, remade, value, belgians, levied, anemone,
# Nearest to can: at, meaningful, lse, due, disarming, extensively, sfp, intervocalic,
# Nearest to heavy: akhmatova, matching, late, caron, dark, lend, had, misspelled,
# Nearest to operating: indicts, sampler, sterile, browser, stele, pretense, coldcut, folds,
# Nearest to active: branded, lynched, elements, moved, voter, muselar, encompass, glam,
# Nearest to versions: imagining, waits, bulge, repentant, eifel, dotted, reelected, shaikh,
# Nearest to prince: fable, was, annex, tightly, supporter, stater, multitude, problematic,
# Nearest to except: colonists, attending, rosenzweig, pointed, sizes, prehistory, skipping, moody,
# Nearest to san: rival, cuckoo, facundo, amon, matrices, frisch, ripken, art,
# Nearest to applied: espa, untrue, ban, engine, objections, innovation, tone, dyed,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7748 0.4362 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7622 0.4307 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7240 0.4323 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7137 0.4296 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7243 0.4330 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6824 0.4378 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7124 0.4306 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7085 0.4288 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7105 0.4310 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6908 0.4323 sec/batch
# Nearest to history: homogenic, foote, authorization, sc, johan, ditches, commune, tradition,
# Nearest to the: renovated, into, bill, peculiar, concession, flaws, bathe, markedly,
# Nearest to into: the, handle, hemicellulose, provenance, ancillary, contraction, londoners, corda,
# Nearest to however: granta, harrow, flavored, dorsey, level, walked, iteratively, mylar,
# Nearest to its: hurry, waterline, twin, ceremony, cheat, meda, nebula, galen,
# Nearest to has: restricting, omnipotence, lungs, hams, feeling, impossible, barrels, repairs,
# Nearest to used: belgians, levied, anemone, value, tide, fatty, remade, blenheim,
# Nearest to can: disarming, meaningful, lse, sfp, extensively, empirically, at, broccoli,
# Nearest to heavy: akhmatova, caron, misspelled, matching, had, tz, stanley, dark,
# Nearest to operating: indicts, pretense, sampler, browser, sterile, coldcut, stele, folds,
# Nearest to active: branded, lynched, muselar, elements, moved, infty, alda, hanukkah,
# Nearest to versions: imagining, reelected, symbolise, eifel, painfully, dotted, bulge, waits,
# Nearest to prince: fable, supporter, annex, kee, was, stater, onward, three,
# Nearest to except: colonists, rosenzweig, skipping, pointed, prehistory, attending, scofield, sizes,
# Nearest to san: rival, cuckoo, amon, facundo, frisch, art, restitution, rechristened,
# Nearest to applied: espa, ban, untrue, pragmatically, objections, laos, engine, innovation,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6646 0.4431 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6869 0.4312 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6228 0.4345 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6139 0.4313 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6388 0.4288 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6378 0.4295 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6064 0.3108 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5513 0.4303 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5270 0.4339 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5301 0.4446 sec/batch
# Nearest to history: homogenic, foote, authorization, sc, johan, ditches, commune, tradition,
# Nearest to the: into, renovated, concession, peculiar, flaws, yards, bengali, bathe,
# Nearest to into: the, provenance, hemicellulose, handle, londoners, corda, ancillary, xli,
# Nearest to however: granta, harrow, flavored, level, iteratively, dorsey, walked, imperfections,
# Nearest to its: hurry, waterline, twin, ceremony, cheat, meda, galen, sliding,
# Nearest to has: restricting, omnipotence, hams, lungs, istv, electrochemical, feeling, cockpits,
# Nearest to used: belgians, anemone, value, partway, fatty, levied, restricting, freezing,
# Nearest to can: meaningful, disarming, lse, due, empirically, broccoli, superchargers, sfp,
# Nearest to heavy: akhmatova, caron, misspelled, riffs, tz, dark, ruff, provoking,
# Nearest to operating: indicts, browser, pretense, sampler, coldcut, sterile, folds, stele,
# Nearest to active: branded, lynched, elements, alda, hanukkah, infty, glam, muselar,
# Nearest to versions: imagining, reelected, waits, painfully, dotted, subroutine, symbolise, ekron,
# Nearest to prince: fable, supporter, kee, three, saxony, stater, lexicographers, annex,
# Nearest to except: colonists, scofield, rosenzweig, pointed, prehistory, cav, sizes, attending,
# Nearest to san: rival, cuckoo, frisch, amon, facundo, ripken, restitution, rechristened,
# Nearest to applied: espa, untrue, ban, objections, pragmatically, engine, mouthpieces, laos,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5366 0.4535 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5335 0.4320 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4694 0.4306 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5249 0.4298 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4950 0.4294 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4857 0.4317 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4573 0.4325 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4077 0.4340 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4233 0.4336 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4186 0.4373 sec/batch
# Nearest to history: homogenic, foote, sc, authorization, tradition, ditches, johan, commune,
# Nearest to the: bengali, into, peculiar, concession, vultures, flaws, dt, markedly,
# Nearest to into: the, handle, corda, hemicellulose, provenance, londoners, amber, matchup,
# Nearest to however: granta, level, mylar, imperfections, harrow, flavored, iteratively, dorsey,
# Nearest to its: hurry, waterline, meda, twin, cheat, galen, ceremony, plains,
# Nearest to has: restricting, lungs, istv, cockpits, omnipotence, electrochemical, barred, hams,
# Nearest to used: anemone, belgians, value, partway, fatty, phosphorus, remade, systems,
# Nearest to can: meaningful, empirically, disarming, xy, broccoli, quantity, lse, superchargers,
# Nearest to heavy: riffs, ruff, misspelled, tz, provoking, scudetto, akhmatova, barrels,
# Nearest to operating: indicts, browser, sampler, pretense, output, coldcut, sterile, memory,
# Nearest to active: lynched, branded, elements, hanukkah, muselar, infty, comprehend, alda,
# Nearest to versions: imagining, ekron, subroutine, painfully, reelected, dotted, waits, forsey,
# Nearest to prince: fable, supporter, kee, saxony, grandson, lexicographers, stater, annex,
# Nearest to except: colonists, rosenzweig, scofield, pointed, cav, attending, initiations, sizes,
# Nearest to san: rival, frisch, facundo, cuckoo, ripken, amon, rechristened, wreck,
# Nearest to applied: espa, untrue, pragmatically, objections, ban, mouthpieces, engine, crystallized,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4518 0.4402 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4240 0.4286 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4472 0.4277 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4164 0.4300 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4099 0.4253 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4418 0.4281 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3613 0.4269 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3714 0.4253 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3898 0.4301 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3667 0.4292 sec/batch
# Nearest to history: homogenic, foote, sc, tradition, ditches, authorization, dps, commune,
# Nearest to the: bengali, concession, renovated, bathe, peculiar, into, markedly, dt,
# Nearest to into: the, provenance, corda, cav, handle, hemicellulose, xli, matchup,
# Nearest to however: granta, level, mylar, harrow, imperfections, flavored, dynamism, iteratively,
# Nearest to its: hurry, waterline, meda, twin, cheat, reichenbach, was, plains,
# Nearest to has: istv, electrochemical, lungs, barred, amputees, omnipotence, hams, restricting,
# Nearest to used: anemone, belgians, partway, fatty, specialize, value, remade, tonic,
# Nearest to can: meaningful, empirically, xy, disarming, superchargers, assuming, quantity, compress,
# Nearest to heavy: riffs, misspelled, ruff, carbines, tz, barrels, shamir, provoking,
# Nearest to operating: browser, indicts, sampler, pretense, output, coldcut, sterile, memory,
# Nearest to active: lynched, branded, hanukkah, muselar, alda, infty, comprehend, elements,
# Nearest to versions: imagining, ekron, subroutine, painfully, waits, dotted, reelected, forsey,
# Nearest to prince: supporter, fable, was, grandson, kee, lexicographers, saxony, asses,
# Nearest to except: rosenzweig, colonists, scofield, pointed, specs, pave, cav, mrsi,
# Nearest to san: rival, cuckoo, frisch, facundo, amon, rechristened, ripken, ska,
# Nearest to applied: espa, untrue, pragmatically, mouthpieces, objections, ban, engine, freesite,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3882 0.4363 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4097 0.4294 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3443 0.4290 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3709 0.4290 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3829 0.4274 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3640 0.4304 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3833 0.4288 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3880 0.4281 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3447 0.4309 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3330 0.4263 sec/batch
# Nearest to history: homogenic, foote, tradition, sc, dps, tamazight, ditches, commune,
# Nearest to the: of, into, concession, markedly, peculiar, bengali, and, bathe,
# Nearest to into: the, provenance, corda, hemicellulose, cav, xli, matchup, londoners,
# Nearest to however: mylar, granta, level, imperfections, dynamism, informers, harrow, flavored,
# Nearest to its: hurry, waterline, meda, twin, cheat, galen, was, reichenbach,
# Nearest to has: amputees, istv, barred, electrochemical, gwyneth, guarantees, dogsled, hams,
# Nearest to used: partway, anemone, belgians, specialize, mycoplasma, fatty, component, tubes,
# Nearest to can: disarming, meaningful, xy, compress, superchargers, empirically, sfp, broccoli,
# Nearest to heavy: riffs, carbines, shamir, ruff, barrels, misspelled, dark, tz,
# Nearest to operating: browser, sampler, indicts, output, pretense, coldcut, mode, memory,
# Nearest to active: lynched, branded, hanukkah, elements, muselar, juneau, alda, arana,
# Nearest to versions: imagining, ekron, subroutine, painfully, studio, forsey, mixolydian, dotted,
# Nearest to prince: supporter, fable, grandson, was, lexicographers, saxony, kee, cadet,
# Nearest to except: rosenzweig, colonists, scofield, pointed, pave, blazon, cav, initiations,
# Nearest to san: rival, amon, facundo, frisch, rechristened, cuckoo, ripken, wreck,
# Nearest to applied: espa, untrue, mouthpieces, objections, ban, pragmatically, freesite, crystallized,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3573 0.4385 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2924 0.4326 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3487 0.4285 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3716 0.4276 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3626 0.4362 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2919 0.4288 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2847 0.4246 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3732 0.4279 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2308 0.4304 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3071 0.4291 sec/batch
# Nearest to history: homogenic, tradition, foote, tamazight, dps, sc, humanities, kung,
# Nearest to the: concession, into, bathe, bengali, of, renovated, peculiar, magnitude,
# Nearest to into: the, corda, cav, provenance, londoners, xli, handle, matchup,
# Nearest to however: mylar, granta, harrow, dynamism, level, imperfections, informers, deluded,
# Nearest to its: hurry, waterline, galen, twin, meda, tourist, cheat, poussin,
# Nearest to has: gwyneth, istv, electrochemical, dogsled, crawling, guarantees, barred, burkina,
# Nearest to used: partway, anemone, tubes, specialize, mycoplasma, belgians, fatty, tonic,
# Nearest to can: meaningful, disarming, compress, xy, superchargers, empirically, sfp, assuming,
# Nearest to heavy: riffs, dark, barrels, misspelled, carbines, shamir, ruff, uncommon,
# Nearest to operating: browser, sampler, indicts, coldcut, pretense, modify, output, ported,
# Nearest to active: lynched, branded, hanukkah, malfeasance, decent, eca, encompass, homotopy,
# Nearest to versions: imagining, ekron, subroutine, painfully, studio, forsey, dotted, emulation,
# Nearest to prince: supporter, grandson, fable, saxony, lexicographers, cadet, kee, cousin,
# Nearest to except: scofield, colonists, rosenzweig, pointed, blazon, pave, trollh, chisinau,
# Nearest to san: rival, amon, cuckoo, facundo, wreck, rechristened, frisch, crafts,
# Nearest to applied: espa, untrue, mouthpieces, ban, objections, pragmatically, freesite, crystallized,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2823 0.4331 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3016 0.4300 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3270 0.1881 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2698 0.4305 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2452 0.4297 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2179 0.4287 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2333 0.4292 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2178 0.4261 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2154 0.4314 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1647 0.4290 sec/batch
# Nearest to history: homogenic, foote, tradition, tamazight, sc, humanities, millennium, dps,
# Nearest to the: of, bengali, into, concession, bathe, renovated, declares, arid,
# Nearest to into: the, cav, corda, provenance, handle, londoners, teos, stabilizing,
# Nearest to however: mylar, level, dynamism, harrow, granta, imperfections, converters, flavored,
# Nearest to its: hurry, waterline, twin, meda, tourist, plains, galen, cheat,
# Nearest to has: gwyneth, dogsled, istv, burkina, electrochemical, barred, obstructed, hams,
# Nearest to used: partway, belgians, anemone, tubes, overwork, mycoplasma, specialize, tonic,
# Nearest to can: meaningful, compress, disarming, xy, superchargers, empirically, sfp, bilinear,
# Nearest to heavy: riffs, carbines, barrels, ruff, dark, shamir, army, uncommon,
# Nearest to operating: browser, sampler, indicts, pretense, coldcut, ported, drives, output,
# Nearest to active: branded, lynched, decent, eca, alda, elements, hanukkah, encompass,
# Nearest to versions: subroutine, imagining, emulation, ekron, painfully, wrench, toolbox, studio,
# Nearest to prince: grandson, supporter, saxony, cadet, fable, lexicographers, cousin, was,
# Nearest to except: colonists, scofield, rosenzweig, pointed, trollh, mrsi, blazon, cav,
# Nearest to san: rival, wreck, amon, rechristened, cuckoo, crafts, facundo, frisch,
# Nearest to applied: espa, untrue, objections, mouthpieces, ban, freesite, carve, dyed,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2439 0.4346 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2037 0.4300 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2118 0.4289 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1507 0.4285 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1999 0.4290 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1832 0.4299 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1635 0.4253 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1989 0.4271 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1839 0.4276 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1740 0.4277 sec/batch
# Nearest to history: foote, tradition, homogenic, humanities, sc, millennium, archaeological, translations,
# Nearest to the: of, bathe, dt, a, into, and, divisibility, unwind,
# Nearest to into: the, cav, corda, handle, enough, teos, xli, provenance,
# Nearest to however: mylar, level, dynamism, granta, imperfections, harrow, deluded, flavored,
# Nearest to its: hurry, waterline, galen, tourist, yup, twin, meda, slipper,
# Nearest to has: gwyneth, istv, dogsled, oxidize, electrochemical, lungs, densities, burkina,
# Nearest to used: partway, belgians, tubes, anemone, overwork, unconventional, specialize, mycoplasma,
# Nearest to can: meaningful, compress, disarming, empirically, xy, superchargers, bilinear, assuming,
# Nearest to heavy: carbines, barrels, riffs, ruff, dark, army, soldiers, lighter,
# Nearest to operating: browser, sampler, indicts, drives, ported, pretense, coldcut, output,
# Nearest to active: branded, lynched, decent, hanukkah, eca, alda, encompass, elements,
# Nearest to versions: subroutine, imagining, emulation, ekron, painfully, toolbox, wrench, studio,
# Nearest to prince: grandson, cadet, fable, supporter, saxony, lexicographers, cousin, stater,
# Nearest to except: scofield, colonists, rosenzweig, pointed, mrsi, blazon, diwan, trollh,
# Nearest to san: rival, wreck, rechristened, facundo, crafts, amon, cuckoo, frisch,
# Nearest to applied: espa, untrue, mouthpieces, ban, objections, freesite, carve, akm,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2090 0.4343 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2271 0.4268 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1775 0.4319 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1573 0.4270 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1565 0.4268 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1919 0.4278 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2062 0.4294 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1430 0.4268 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1414 0.4297 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1662 0.4300 sec/batch
# Nearest to history: foote, humanities, homogenic, sc, tradition, kung, library, millennium,
# Nearest to the: of, dt, a, bathe, and, tewahedo, bengali, into,
# Nearest to into: cav, corda, provenance, londoners, the, teos, xli, handle,
# Nearest to however: mylar, level, harrow, dynamism, granta, imperfections, deluded, flavored,
# Nearest to its: hurry, waterline, twin, yup, galen, meda, cheat, poussin,
# Nearest to has: gwyneth, dogsled, istv, burkina, electrochemical, hams, lecompton, amputees,
# Nearest to used: partway, belgians, anemone, specialize, tubes, mycoplasma, overwork, tonic,
# Nearest to can: meaningful, compress, disarming, bilinear, empirically, xy, superchargers, assuming,
# Nearest to heavy: carbines, riffs, barrels, dark, ruff, army, shamir, lighter,
# Nearest to operating: browser, sampler, indicts, drives, coldcut, ported, pretense, matching,
# Nearest to active: lynched, branded, alda, decent, eca, microchip, hanukkah, elements,
# Nearest to versions: imagining, subroutine, ekron, painfully, emulation, zapruder, wrench, fil,
# Nearest to prince: grandson, supporter, fable, cadet, cousin, lexicographers, saxony, was,
# Nearest to except: colonists, scofield, pointed, rosenzweig, diwan, blazon, trollh, mrsi,
# Nearest to san: amon, rival, rechristened, crafts, facundo, wreck, cuckoo, wynn,
# Nearest to applied: espa, untrue, mouthpieces, objections, freesite, carve, ban, untersuchungen,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2186 0.4325 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1581 0.4300 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1635 0.4308 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1783 0.4297 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1322 0.4285 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1405 0.4265 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1829 0.4320 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1114 0.4321 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1736 0.4304 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1948 0.4290 sec/batch
# Nearest to history: foote, tradition, archaeological, humanities, tamazight, homogenic, millennium, library,
# Nearest to the: of, and, a, bathe, events, concession, bengali, into,
# Nearest to into: the, teos, xli, londoners, provenance, cav, corda, stabilizing,
# Nearest to however: mylar, level, dynamism, harrow, constables, granta, informers, imperfections,
# Nearest to its: hurry, waterline, collapsed, tourist, owing, poussin, galen, economic,
# Nearest to has: gwyneth, dogsled, istv, fiorentino, burkina, lecompton, electrochemical, schliemann,
# Nearest to used: belgians, partway, anemone, overwork, unconventional, specialize, otomo, mycoplasma,
# Nearest to can: meaningful, compress, disarming, superchargers, empirically, chickie, sfp, bilinear,
# Nearest to heavy: carbines, riffs, barrels, dark, ruff, shamir, army, late,
# Nearest to operating: sampler, browser, indicts, coldcut, pretense, drives, ported, matching,
# Nearest to active: lynched, branded, alda, eca, defeat, malfeasance, elements, hanukkah,
# Nearest to versions: imagining, subroutine, ekron, painfully, emulation, zapruder, wrench, fil,
# Nearest to prince: grandson, supporter, cousin, fable, lexicographers, was, announcing, saxony,
# Nearest to except: colonists, scofield, diwan, blazon, pointed, impeached, rosenzweig, trollh,
# Nearest to san: rival, amon, crafts, facundo, rechristened, wreck, cuckoo, wynn,
# Nearest to applied: espa, untrue, ban, mouthpieces, untersuchungen, objections, freesite, carve,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2296 0.4324 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1241 0.4295 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1455 0.4268 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1358 0.4287 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0505 0.4281 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1475 0.4288 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1455 0.4286 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1224 0.4275 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1890 0.0690 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1511 0.4280 sec/batch
# Nearest to history: humanities, archaeological, library, foote, millennium, tamazight, tradition, kung,
# Nearest to the: of, and, a, concession, into, tewahedo, peculiar, as,
# Nearest to into: the, cav, corda, stabilizing, provenance, teos, enough, londoners,
# Nearest to however: mylar, level, harrow, dynamism, deluded, imperfections, granta, constables,
# Nearest to its: hurry, waterline, owing, collapsed, twin, poussin, meda, galen,
# Nearest to has: dogsled, gwyneth, burkina, istv, schliemann, lecompton, electrochemical, fiorentino,
# Nearest to used: partway, belgians, overwork, anemone, unconventional, tubes, specialize, mycoplasma,
# Nearest to can: meaningful, compress, disarming, chickie, solvable, bilinear, superchargers, empirically,
# Nearest to heavy: carbines, riffs, dark, barrels, ruff, army, shamir, lighter,
# Nearest to operating: browser, sampler, coldcut, ported, indicts, pretense, matching, gui,
# Nearest to active: lynched, eca, branded, defeat, alda, elements, homotopy, decent,
# Nearest to versions: imagining, subroutine, emulation, painfully, zapruder, ekron, gui, spawned,
# Nearest to prince: cousin, grandson, fable, supporter, lexicographers, cadet, announcing, saxony,
# Nearest to except: scofield, colonists, diwan, blazon, pointed, specs, trollh, pave,
# Nearest to san: amon, rival, crafts, facundo, rechristened, cuckoo, wreck, ripken,
# Nearest to applied: espa, untrue, ban, mouthpieces, freesite, untersuchungen, akm, carve,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0858 0.4383 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0696 0.4293 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0853 0.4290 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0526 0.4300 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0735 0.4294 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0161 0.4276 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0845 0.4281 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0734 0.4285 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1299 0.4274 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0321 0.4270 sec/batch
# Nearest to history: archaeological, library, millennium, foote, tamazight, homogenic, humanities, tradition,
# Nearest to the: of, and, a, into, in, before, as, with,
# Nearest to into: the, cav, stabilizing, corda, provenance, enough, teos, cab,
# Nearest to however: mylar, level, harrow, dynamism, ko, imperfections, constables, deluded,
# Nearest to its: hurry, waterline, owing, collapsed, twin, poussin, meda, slipper,
# Nearest to has: gwyneth, dogsled, burkina, lecompton, istv, schliemann, oxidize, remain,
# Nearest to used: partway, tubes, belgians, overwork, anemone, unconventional, remade, mycoplasma,
# Nearest to can: compress, meaningful, chickie, xy, bilinear, solvable, disarming, superchargers,
# Nearest to heavy: carbines, riffs, barrels, army, ruff, dark, shamir, lighter,
# Nearest to operating: browser, sampler, coldcut, ported, gui, drives, indicts, pretense,
# Nearest to active: branded, lynched, eca, deployment, microchip, homotopy, aliphatic, elements,
# Nearest to versions: subroutine, emulation, imagining, zapruder, painfully, gui, ekron, wrench,
# Nearest to prince: cousin, grandson, fable, cadet, lexicographers, announcing, saxony, supporter,
# Nearest to except: scofield, diwan, colonists, impeached, trollh, case, pointed, ecclesiastic,
# Nearest to san: rival, amon, rechristened, facundo, crafts, ripken, cuckoo, holcomb,
# Nearest to applied: espa, untrue, mouthpieces, untersuchungen, frequencies, ban, freesite, carve,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0260 0.4327 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0220 0.4269 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0405 0.4287 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0679 0.4256 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0675 0.4302 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0593 0.4273 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0694 0.4272 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1079 0.4255 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0682 0.4288 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0513 0.4262 sec/batch
# Nearest to history: archaeological, library, homogenic, humanities, foote, millennium, daf, dps,
# Nearest to the: of, and, a, into, in, coordinates, dt, before,
# Nearest to into: the, cav, stabilizing, provenance, enough, corda, xli, cab,
# Nearest to however: mylar, level, harrow, dynamism, deluded, being, ko, imperfections,
# Nearest to its: hurry, waterline, meda, collapsed, geomagnetic, twin, elliptical, owing,
# Nearest to has: gwyneth, dogsled, istv, burkina, oxidize, electrochemical, tvs, lecompton,
# Nearest to used: partway, belgians, unconventional, overwork, tubes, anemone, remade, specialize,
# Nearest to can: compress, meaningful, solvable, bilinear, chickie, xy, broccoli, want,
# Nearest to heavy: carbines, riffs, barrels, dark, ruff, army, shamir, lighter,
# Nearest to operating: sampler, browser, indicts, coldcut, pretense, ported, drives, bbs,
# Nearest to active: lynched, eca, microchip, decent, branded, deployment, alda, encompass,
# Nearest to versions: subroutine, emulation, zapruder, imagining, painfully, ekron, cygwin, melons,
# Nearest to prince: cousin, grandson, fable, cadet, announcing, saxony, lexicographers, equites,
# Nearest to except: case, scofield, diwan, impeached, pave, colonists, specs, rosenzweig,
# Nearest to san: rival, amon, rechristened, crafts, facundo, cuckoo, shelves, wreck,
# Nearest to applied: espa, untrue, ban, untersuchungen, mouthpieces, vcr, freesite, frequencies,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0565 0.4325 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0920 0.4279 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0743 0.4270 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0959 0.4257 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0848 0.4307 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0365 0.4278 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0654 0.4282 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0484 0.4287 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0935 0.4324 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0585 0.4293 sec/batch
# Nearest to history: archaeological, library, millennium, humanities, tamazight, prehistory, foote, tradition,
# Nearest to the: of, and, a, in, into, before, as, from,
# Nearest to into: the, cav, stabilizing, pharaohs, teos, provenance, xli, londoners,
# Nearest to however: mylar, harrow, dynamism, level, constables, deluded, being, ko,
# Nearest to its: hurry, collapsed, waterline, poussin, meda, owing, downplay, changed,
# Nearest to has: gwyneth, dogsled, burkina, istv, gatherers, lecompton, is, electrochemical,
# Nearest to used: partway, belgians, anemone, unconventional, overwork, wallabies, remade, tubes,
# Nearest to can: meaningful, compress, solvable, bilinear, chickie, disarming, broccoli, sfp,
# Nearest to heavy: carbines, riffs, barrels, shamir, dark, ruff, fictionalized, matching,
# Nearest to operating: sampler, indicts, browser, drives, coldcut, pretense, ported, castiglione,
# Nearest to active: lynched, eca, deployment, encompass, microchip, defeat, decent, branded,
# Nearest to versions: emulation, subroutine, zapruder, imagining, gui, ekron, painfully, cygwin,
# Nearest to prince: cousin, grandson, announcing, crown, fable, cadet, equites, supporter,
# Nearest to except: case, scofield, runge, blazon, diwan, impeached, colonists, rosenzweig,
# Nearest to san: amon, rival, crafts, rechristened, facundo, cuckoo, wreck, shelves,
# Nearest to applied: espa, untrue, ban, untersuchungen, mouthpieces, frequencies, carve, freesite,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0519 0.4362 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0007 0.4274 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0355 0.4279 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0707 0.4295 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0532 0.4312 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1683 0.4366 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1305 0.4265 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0311 0.4275 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0679 0.4262 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0425 0.4248 sec/batch
# Nearest to history: archaeological, millennium, library, humanities, foote, prehistory, tamazight, dps,
# Nearest to the: of, and, a, in, into, coordinates, patter, as,
# Nearest to into: the, cav, stabilizing, teos, provenance, enough, xli, pharaohs,
# Nearest to however: harrow, mylar, dynamism, ko, level, deluded, informers, constables,
# Nearest to its: poussin, owing, hurry, collapsed, meda, waterline, bordered, downplay,
# Nearest to has: burkina, dogsled, istv, gwyneth, is, convenes, gatherers, schliemann,
# Nearest to used: partway, anemone, belgians, unconventional, wallabies, tubes, overwork, mycoplasma,
# Nearest to can: compress, meaningful, bilinear, want, fraca, xy, solvable, activex,
# Nearest to heavy: carbines, riffs, barrels, late, dark, shamir, fatboy, fictionalized,
# Nearest to operating: sampler, browser, pretense, indicts, dow, coldcut, drives, ported,
# Nearest to active: lynched, eca, deployment, encompass, branded, synthesizer, homotopy, microchip,
# Nearest to versions: subroutine, emulation, imagining, zapruder, painfully, gui, ekron, toolbox,
# Nearest to prince: cousin, grandson, announcing, crown, supporter, fable, equites, reigning,
# Nearest to except: case, blazon, scofield, diwan, colonists, runge, impeached, rosenzweig,
# Nearest to san: rival, amon, crafts, francisco, facundo, rechristened, wreck, cuckoo,
# Nearest to applied: espa, ban, untrue, untersuchungen, mouthpieces, sociolinguistics, crystallized, frequencies,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9784 0.4325 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0067 0.4274 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0299 0.4295 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0376 0.4302 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0845 0.4292 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0203 0.3772 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0211 0.4299 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9898 0.4282 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0057 0.4273 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9897 0.4311 sec/batch
# Nearest to history: archaeological, millennium, prehistory, library, humanities, ditches, foote, tamazight,
# Nearest to the: of, and, into, a, in, before, tewahedo, coordinates,
# Nearest to into: the, cav, stabilizing, teos, enough, provenance, corda, haggai,
# Nearest to however: harrow, dynamism, mylar, deluded, constables, level, goldman, ko,
# Nearest to its: bordered, hurry, owing, meda, poussin, waterline, adventureland, twin,
# Nearest to has: dogsled, burkina, gwyneth, is, gatherers, istv, alphabet, reggae,
# Nearest to used: belgians, partway, tubes, anemone, wallabies, uses, unconventional, mycoplasma,
# Nearest to can: compress, meaningful, hydroxides, bilinear, solvable, want, pulling, chickie,
# Nearest to heavy: carbines, riffs, barrels, shamir, lighter, late, matching, ruff,
# Nearest to operating: sampler, browser, coldcut, ported, dow, pretense, indicts, accelerator,
# Nearest to active: lynched, eca, deployment, encompass, alda, gestae, microchip, branded,
# Nearest to versions: subroutine, emulation, imagining, version, zapruder, painfully, cygwin, gui,
# Nearest to prince: cousin, grandson, reigning, crown, announcing, fable, brabant, supporter,
# Nearest to except: case, scofield, blazon, colonists, diwan, impeached, bsnl, runge,
# Nearest to san: rival, francisco, amon, crafts, facundo, rechristened, shelves, wreck,
# Nearest to applied: espa, ban, untrue, sociolinguistics, frequencies, carve, mouthpieces, freesite,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9804 0.4344 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9640 0.4294 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0305 0.4267 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0245 0.4282 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0144 0.4284 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0099 0.4305 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9125 0.4299 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9539 0.4292 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9336 0.4250 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9701 0.4263 sec/batch
# Nearest to history: archaeological, millennium, library, prehistory, foote, ditches, humanities, homogenic,
# Nearest to the: of, and, in, a, before, into, with, mvp,
# Nearest to into: the, cav, stabilizing, teos, haggai, enough, vci, provenance,
# Nearest to however: mylar, harrow, level, deluded, that, dynamism, being, ko,
# Nearest to its: hurry, changed, meda, bordered, waterline, owing, tourist, famicom,
# Nearest to has: is, burkina, have, gwyneth, istv, gatherers, dogsled, and,
# Nearest to used: belgians, tubes, partway, anemone, wallabies, unconventional, remade, mycoplasma,
# Nearest to can: compress, meaningful, want, bilinear, solvable, xy, because, disarming,
# Nearest to heavy: carbines, riffs, barrels, lighter, cimbri, uncommon, wielding, late,
# Nearest to operating: browser, sampler, pretense, indicts, raft, ocaml, coldcut, dow,
# Nearest to active: lynched, eca, deployment, encompass, microchip, synthesizer, branded, alda,
# Nearest to versions: subroutine, imagining, zapruder, emulation, painfully, cygwin, ekron, version,
# Nearest to prince: cousin, grandson, announcing, fable, reigning, equites, brabant, crown,
# Nearest to except: case, diwan, scofield, blazon, colonists, impeached, umami, rosenzweig,
# Nearest to san: francisco, rival, amon, crafts, facundo, rechristened, shelves, cuckoo,
# Nearest to applied: espa, ban, untrue, sociolinguistics, synchrotron, frequencies, shaped, mouthpieces,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9678 0.4358 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0136 0.4268 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9492 0.4280 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0228 0.4288 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0332 0.4275 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9582 0.4284 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0052 0.4300 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9901 0.4292 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9636 0.4281 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0003 0.4269 sec/batch
# Nearest to history: archaeological, millennium, library, foote, prehistory, ditches, homogenic, humanities,
# Nearest to the: of, and, in, a, into, with, is, as,
# Nearest to into: the, cav, stabilizing, provenance, haggai, teos, enough, londoners,
# Nearest to however: harrow, mylar, level, deluded, goldman, that, dynamism, ko,
# Nearest to its: meda, poussin, hurry, waterline, is, disparate, bordered, sliding,
# Nearest to has: is, gwyneth, istv, burkina, have, gatherers, dogsled, tvs,
# Nearest to used: belgians, partway, tubes, remade, anemone, unconventional, wallabies, uses,
# Nearest to can: compress, solvable, meaningful, bilinear, want, pulling, fraca, disarming,
# Nearest to heavy: carbines, riffs, barrels, lighter, cimbri, wielding, fatboy, matching,
# Nearest to operating: sampler, indicts, pretense, browser, raft, accelerator, dow, coldcut,
# Nearest to active: lynched, eca, deployment, synthesizer, microchip, alda, encompass, cooperation,
# Nearest to versions: subroutine, imagining, zapruder, cygwin, emulation, baggage, version, ekron,
# Nearest to prince: cousin, reigning, grandson, crown, announcing, equites, fable, brabant,
# Nearest to except: case, diwan, scofield, colonists, specs, impeached, rosenzweig, philippians,
# Nearest to san: francisco, amon, rival, crafts, facundo, rechristened, unmixed, shelves,
# Nearest to applied: espa, ban, untrue, synchrotron, sociolinguistics, shaped, untersuchungen, freesite,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0249 0.4390 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9686 0.4314 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9787 0.4280 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0014 0.4287 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9878 0.4297 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0091 0.4281 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9668 0.4281 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9726 0.4302 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9674 0.4261 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0076 0.4307 sec/batch
# Nearest to history: archaeological, millennium, prehistory, library, tamazight, foote, humanities, travers,
# Nearest to the: of, and, in, a, into, by, from, as,
# Nearest to into: the, stabilizing, teos, cav, haggai, provenance, pharaohs, enough,
# Nearest to however: harrow, mylar, deluded, level, goldman, dynamism, ko, constables,
# Nearest to its: collapsed, meda, poussin, owing, bordered, changed, vouli, is,
# Nearest to has: is, gwyneth, the, istv, burkina, have, and, gatherers,
# Nearest to used: partway, belgians, anemone, wiktionary, unconventional, remade, uses, provers,
# Nearest to can: compress, want, disarming, meaningful, disadvantages, pulling, hydroxides, solvable,
# Nearest to heavy: carbines, riffs, barrels, late, fatboy, matching, cimbri, shamir,
# Nearest to operating: dow, browser, raft, pretense, marshland, indicts, accelerator, sampler,
# Nearest to active: deployment, lynched, eca, synthesizer, microchip, encompass, cooperation, aliphatic,
# Nearest to versions: imagining, subroutine, zapruder, emulation, version, cygwin, ekron, estrangement,
# Nearest to prince: cousin, announcing, crown, reigning, grandson, equites, fable, asses,
# Nearest to except: colonists, case, diwan, scofield, impeached, rosenzweig, specs, blazon,
# Nearest to san: francisco, amon, rival, crafts, facundo, rechristened, unmixed, buxton,
# Nearest to applied: espa, ban, untrue, sociolinguistics, synchrotron, untersuchungen, frequencies, shaped,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9693 0.4374 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1037 0.4288 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0081 0.4275 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0387 0.4282 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9201 0.4299 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9454 0.4251 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9885 0.4275 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9042 0.4324 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0129 0.4297 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9893 0.4292 sec/batch
# ...
# Nearest to the: of, a, in, and, by, from, is, for,
# Nearest to into: the, bladders, then, haggai, vci, cav, teos, continued,
# Nearest to however: but, now, although, that, the, also, harrow, it,
# Nearest to its: is, bordered, the, also, vouli, s, unaltered, reversed,
# Nearest to has: is, and, the, also, a, have, because, discant,
# Nearest to used: remade, instead, use, widely, minicomputer, uses, partway, often,
# Nearest to can: are, want, it, because, disadvantages, sanc, compress, kooper,
# Nearest to heavy: carbines, riffs, barrels, fatboy, counterparts, uncommon, caron, chagas,
# Nearest to operating: marshland, multiprogramming, raft, concomitant, ocaml, kitchens, expand, castiglione,
# Nearest to active: eca, amplifying, lynched, future, deployment, latino, feroze, synthesizer,
# Nearest to versions: version, subroutine, grille, imagining, nightmare, baggage, cygwin, estrangement,
# Nearest to prince: announcing, consort, asses, cousin, reigning, carnahan, saxe, miya,
# Nearest to except: protons, interfere, case, diwan, breaches, lempel, stanfield, philippians,
# Nearest to san: francisco, jose, california, escalate, facundo, crafts, rival, chl,
# Nearest to applied: espa, electrochemistry, frequencies, immunization, sociolinguistics, vcr, synchrotron, electrolyte,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8417 0.4344 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8432 0.4323 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8384 0.4287 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8309 0.4309 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8735 0.4321 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9042 0.4307 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8672 0.4311 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8431 0.4273 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8936 0.4310 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8498 0.4315 sec/batch
# Nearest to history: archaeological, millennium, prehistory, topics, janszoon, library, historical, handbook,
# Nearest to the: of, and, in, from, by, a, is, for,
# Nearest to into: the, haggai, bladders, then, teos, continued, urnfield, finally,
# Nearest to however: but, now, although, the, that, also, it, never,
# Nearest to its: is, the, of, s, also, bordered, unaltered, has,
# Nearest to has: is, the, and, also, a, because, have, discant,
# Nearest to used: remade, use, instead, widely, uses, partway, minicomputer, additive,
# Nearest to can: are, disadvantages, want, it, sanc, because, solvable, seo,
# Nearest to heavy: riffs, carbines, fatboy, caron, uncommon, counterparts, barrels, chagas,
# Nearest to operating: marshland, multiprogramming, raft, concomitant, ocaml, kitchens, castiglione, indicts,
# Nearest to active: amplifying, eca, lynched, future, deployment, synthesizer, encompass, feroze,
# Nearest to versions: version, nightmare, imagining, subroutine, grille, estrangement, also, baggage,
# Nearest to prince: consort, reigning, announcing, crown, cousin, miya, japan, sandtrout,
# Nearest to except: protons, interfere, diwan, case, lempel, breaches, stanfield, runge,
# Nearest to san: francisco, jose, california, escalate, crafts, facundo, amon, chl,
# Nearest to applied: espa, electrochemistry, sociolinguistics, immunization, frequencies, synchrotron, vcr, electrolyte,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8650 0.4350 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8483 0.4285 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8333 0.4305 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8212 0.4279 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8741 0.4311 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8155 0.4332 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9404 0.4301 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8975 0.4289 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8967 0.4288 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8248 0.4306 sec/batch
# Nearest to history: archaeological, millennium, prehistory, janszoon, handbook, topics, timeline, ditches,
# Nearest to the: of, in, and, by, from, a, for, is,
# Nearest to into: the, continued, haggai, then, bladders, finally, eventually, teos,
# Nearest to however: now, although, but, the, also, that, it, options,
# Nearest to its: the, is, of, s, bordered, has, vouli, also,
# Nearest to has: is, the, and, a, also, in, for, its,
# Nearest to used: instead, remade, use, often, uses, partway, additive, auxiliaries,
# Nearest to can: want, disadvantages, because, it, are, seo, sanc, if,
# Nearest to heavy: riffs, carbines, caron, uncommon, counterparts, fatboy, seto, chagas,
# Nearest to operating: marshland, multiprogramming, raft, ocaml, kitchens, concomitant, castiglione, expand,
# Nearest to active: amplifying, eca, lynched, future, deployment, synthesizer, absolved, montenegrins,
# Nearest to versions: version, subroutine, grille, nightmare, labyrinth, lite, imagining, shied,
# Nearest to prince: announcing, consort, miya, cousin, reigning, crown, carnahan, japan,
# Nearest to except: protons, interfere, colonists, inventories, diwan, breaches, stanfield, zak,
# Nearest to san: francisco, jose, escalate, amon, california, kafir, facundo, crafts,
# Nearest to applied: espa, immunization, sociolinguistics, frequencies, ban, electrochemistry, vcr, synchrotron,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7756 0.4303 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8698 0.4284 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7677 0.4315 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8963 0.4293 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8425 0.4290 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8698 0.4309 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9011 0.2069 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8244 0.4313 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8516 0.4289 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8382 0.4353 sec/batch
# Nearest to history: archaeological, millennium, prehistory, janszoon, topics, handbook, timeline, article,
# Nearest to the: of, and, in, a, from, by, is, on,
# Nearest to into: the, then, haggai, continued, bladders, vci, finally, cav,
# Nearest to however: although, now, but, never, also, that, options, harrow,
# Nearest to its: is, the, bordered, also, s, has, of, vouli,
# Nearest to has: is, and, also, the, a, for, discant, have,
# Nearest to used: use, uses, remade, widely, molality, elektron, herbivorous, additive,
# Nearest to can: are, because, want, disadvantages, nudge, judicious, sanc, if,
# Nearest to heavy: riffs, carbines, caron, fatboy, uncommon, counterparts, lena, seto,
# Nearest to operating: marshland, multiprogramming, raft, concomitant, ported, kitchens, expand, ocaml,
# Nearest to active: amplifying, eca, lynched, future, deployment, synthesizer, encompass, montenegrins,
# Nearest to versions: version, subroutine, grille, nightmare, imagining, labyrinth, cygwin, lite,
# Nearest to prince: consort, announcing, reigning, crown, carnahan, miya, renounced, cousin,
# Nearest to except: protons, interfere, exits, stanfield, breaches, colonists, diwan, filth,
# Nearest to san: francisco, jose, california, escalate, crafts, facundo, another, chl,
# Nearest to applied: espa, sociolinguistics, immunization, frequencies, electrochemistry, vcr, ban, synchrotron,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8363 0.4357 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8250 0.4289 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8330 0.4297 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7947 0.4283 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8337 0.4293 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8150 0.4282 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8551 0.4294 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7339 0.4302 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8088 0.4288 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8031 0.4279 sec/batch
# Nearest to history: archaeological, millennium, handbook, article, prehistory, topics, janszoon, library,
# Nearest to the: of, in, and, a, is, from, for, by,
# Nearest to into: the, bladders, then, vci, haggai, of, finally, continued,
# Nearest to however: but, although, now, that, also, the, it, never,
# Nearest to its: is, the, of, also, bordered, s, has, own,
# Nearest to has: is, and, the, also, a, have, in, because,
# Nearest to used: use, instead, as, widely, additive, uses, remade, refer,
# Nearest to can: are, because, it, if, want, be, any, at,
# Nearest to heavy: riffs, carbines, uncommon, caron, fatboy, counterparts, seto, chagas,
# Nearest to operating: marshland, multiprogramming, raft, concomitant, expand, ocaml, ported, kitchens,
# Nearest to active: amplifying, eca, future, lynched, deployment, synthesizer, encompass, latino,
# Nearest to versions: version, subroutine, grille, nightmare, its, labyrinth, baggage, imagining,
# Nearest to prince: announcing, consort, crown, reigning, asses, miya, cousin, renounced,
# Nearest to except: protons, diwan, interfere, inventories, breaches, exits, quartering, case,
# Nearest to san: francisco, jose, california, diego, chl, escalate, unmixed, facundo,
# Nearest to applied: espa, frequencies, electrochemistry, immunization, sociolinguistics, vcr, synchrotron, electrolyte,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7592 0.4315 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8220 0.4280 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8683 0.4281 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8250 0.4308 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7854 0.4282 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8946 0.4317 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8303 0.4324 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8382 0.4312 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8174 0.4273 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8462 0.4313 sec/batch
# Nearest to history: archaeological, handbook, topics, article, millennium, janszoon, library, prehistory,
# Nearest to the: of, in, and, a, is, from, by, for,
# Nearest to into: the, bladders, then, haggai, vci, finally, incorporates, independent,
# Nearest to however: but, also, now, although, that, the, options, it,
# Nearest to its: is, the, also, of, has, bordered, s, vouli,
# Nearest to has: is, the, and, also, a, because, have, in,
# Nearest to used: widely, additive, use, instead, remade, as, uses, the,
# Nearest to can: are, it, want, if, because, disadvantages, any, seo,
# Nearest to heavy: riffs, carbines, caron, fatboy, uncommon, counterparts, seto, trudeau,
# Nearest to operating: marshland, multiprogramming, concomitant, raft, seahawks, expand, scholastic, ocaml,
# Nearest to active: amplifying, lynched, eca, future, deployment, synthesizer, latino, encompass,
# Nearest to versions: version, subroutine, nightmare, grille, labyrinth, baggage, identically, imagining,
# Nearest to prince: consort, reigning, miya, crown, announcing, japan, cousin, princess,
# Nearest to except: interfere, protons, diwan, case, stanfield, unless, breaches, philippians,
# Nearest to san: francisco, jose, california, escalate, diego, facundo, chl, crafts,
# Nearest to applied: espa, frequencies, electrochemistry, immunization, sociolinguistics, synchrotron, vcr, electrolyte,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9021 0.4381 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8050 0.4267 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8248 0.4294 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8253 0.4272 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8785 0.4274 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8421 0.4306 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8203 0.4287 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8450 0.4328 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7985 0.4298 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8139 0.4267 sec/batch
# Nearest to history: archaeological, handbook, millennium, article, topics, prehistory, library, timeline,
# Nearest to the: of, in, and, by, a, from, for, is,
# Nearest to into: the, then, bladders, finally, haggai, hades, teos, vci,
# Nearest to however: but, although, now, the, also, it, that, in,
# Nearest to its: the, is, of, s, also, vouli, has, and,
# Nearest to has: is, the, and, a, also, have, because, in,
# Nearest to used: as, uses, use, instead, widely, in, refer, often,
# Nearest to can: are, it, any, disadvantages, be, if, want, because,
# Nearest to heavy: riffs, carbines, uncommon, caron, fatboy, counterparts, seto, nickname,
# Nearest to operating: marshland, multiprogramming, concomitant, raft, seahawks, coed, nsfnet, dow,
# Nearest to active: amplifying, eca, lynched, deployment, future, synthesizer, tmp, encompass,
# Nearest to versions: version, subroutine, grille, talker, labyrinth, nightmare, tinymud, identically,
# Nearest to prince: consort, crown, announcing, reigning, miya, cousin, japan, princess,
# Nearest to except: protons, interfere, colonists, breaches, quartering, redrawn, inventories, stanfield,
# Nearest to san: francisco, jose, california, escalate, facundo, pontormo, diego, another,
# Nearest to applied: espa, frequencies, immunization, sociolinguistics, electrochemistry, vcr, cosine, reunified,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8597 0.4337 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8205 0.4347 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9042 0.4329 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8829 0.4321 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9013 0.4304 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8509 0.4300 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7844 0.4274 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8057 0.4314 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7290 0.4310 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8629 0.4303 sec/batch
# Nearest to history: archaeological, handbook, millennium, prehistory, topics, library, article, starter,
# Nearest to the: of, in, and, a, from, by, for, is,
# Nearest to into: the, then, bladders, finally, haggai, vci, continued, independent,
# Nearest to however: but, now, also, although, it, the, options, that,
# Nearest to its: the, is, bordered, also, of, s, has, vouli,
# Nearest to has: and, is, the, a, also, for, s, because,
# Nearest to used: instead, additive, uses, use, as, often, refer, remade,
# Nearest to can: are, it, disadvantages, be, want, any, if, will,
# Nearest to heavy: riffs, carbines, uncommon, caron, fatboy, counterparts, seto, playlists,
# Nearest to operating: marshland, multiprogramming, raft, concomitant, ocaml, coed, nsfnet, unix,
# Nearest to active: amplifying, eca, lynched, future, encompass, feroze, deployment, african,
# Nearest to versions: version, talker, grille, subroutine, labyrinth, lite, nightmare, its,
# Nearest to prince: consort, reigning, crown, announcing, miya, princess, cousin, japan,
# Nearest to except: protons, interfere, inventories, quartering, redrawn, stanfield, philippians, case,
# Nearest to san: francisco, jose, another, california, escalate, diego, portland, crafts,
# Nearest to applied: espa, sociolinguistics, immunization, frequencies, electrochemistry, vcr, reunified, ban,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8453 0.4347 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8571 0.4426 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
